# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 10.2 - Deployment via Streamlit

# %% [markdown]
# ### Introduction

# %% [markdown]
# **Note**: This notebook should work on your local machine.
#
# The purpose of this lab is to take you through the process of deploying a machine learning web app on a publicly hosted platform (streamlit.io and optionally render.com). A trained model will be created using the Scikit-learn pipeline (combining loading, preprocessing and training steps), then separate files of Python code and text will need to be completed to make deployment possible. Firstly the app will be deployed to your local machine (so that you can view it in your browser). Once that it is successful, the files will be uploaded to a new repository you create in GitHub and then Streamlit or Render will read from this to host the application via a publicly accessible URL.
#
# The app will take in a text string from a user and output a prediction of whether that string is expressing positive or negative sentiment. The model is created using methods from Module 8 (Natural Language Processing). Since the training data used to create the model is small (300 records), the prediction may only be accurate around 70% of the time. In future you may wish to improve this app's performance or develop your own app in a similar manner.
#
# The following files are needed to create the app (they should be in the same folder as this notebook):
#
# - requirements.txt
# - app.py
# - model.joblib
# - utils.py
# - .streamlit/ (folder containing config.toml)
#
#
# Firstly we will see how a predictive model can be created as a pipe which combines the preprocessing, feature engineering and model training steps. This model is then saved as a joblib pickle file which can be reloaded at any time to avoid retraining.
#
# This trained model can be loaded within your production environment along with required packages and real-time predictions can be made by calling its predict() method.

# %% [markdown]
# Streamlit enables apps to be deployed rapidly with minimal knowledge of HTML or CSS. Some of the key concepts are described at https://docs.streamlit.io/get-started/fundamentals/main-concepts. Sample apps can be seen at https://streamlit.io/gallery.

# %% [markdown]
# ### Model Training and Testing

# %%
# !pip3 install --upgrade streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.39.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (5.4.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (4.25.5)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-17.0.0-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (13.8.1)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (4.11.0)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (6.3.3)
# Collecting watchdog<6,>=2.1.5 (from streamlit)
#   Downloading watchdog-5.0.3-py3-none-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.9 kB ? eta -:--:--
#      ---------------------------------------- 41.9/41.9 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Collecting narwhals>=1.5.2 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.9.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: colorama in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Downloading streamlit-1.39.0-py2.py3-none-any.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.7 MB 4.5 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/8.7 MB 5.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/8.7 MB 4.9 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/8.7 MB 5.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/8.7 MB 5.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/8.7 MB 5.5 MB/s eta 0:00:02
#    ------- -------------------------------- 1.5/8.7 MB 5.4 MB/s eta 0:00:02
#    -------- ------------------------------- 1.8/8.7 MB 5.4 MB/s eta 0:00:02
#    --------- ------------------------------ 2.0/8.7 MB 5.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.3/8.7 MB 5.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.5/8.7 MB 5.3 MB/s eta 0:00:02
#    ------------ --------------------------- 2.8/8.7 MB 5.3 MB/s eta 0:00:02
#    ------------- -------------------------- 2.9/8.7 MB 5.2 MB/s eta 0:00:02
#    -------------- ------------------------- 3.1/8.7 MB 5.1 MB/s eta 0:00:02
#    --------------- ------------------------ 3.4/8.7 MB 5.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.6/8.7 MB 5.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.9/8.7 MB 5.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.1/8.7 MB 5.2 MB/s eta 0:00:01
#    -------------------- ------------------- 4.4/8.7 MB 5.2 MB/s eta 0:00:01
#    --------------------- ------------------ 4.6/8.7 MB 5.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.9/8.7 MB 5.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.2/8.7 MB 5.2 MB/s eta 0:00:01
#    ------------------------ --------------- 5.4/8.7 MB 5.2 MB/s eta 0:00:01
#    ------------------------- -------------- 5.7/8.7 MB 5.2 MB/s eta 0:00:01
#    -------------------------- ------------- 5.9/8.7 MB 5.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.2/8.7 MB 5.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.4/8.7 MB 5.3 MB/s eta 0:00:01
#    ------------------------------ --------- 6.7/8.7 MB 5.3 MB/s eta 0:00:01
#    ------------------------------- -------- 6.8/8.7 MB 5.2 MB/s eta 0:00:01
#    -------------------------------- ------- 7.1/8.7 MB 5.3 MB/s eta 0:00:01
#    --------------------------------- ------ 7.3/8.7 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.5/8.7 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.5/8.7 MB 5.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.7/8.7 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------ --- 8.0/8.7 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 8.1/8.7 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------- -- 8.3/8.7 MB 5.0 MB/s eta 0:00:01
#    -------------------------------------- - 8.5/8.7 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  8.6/8.7 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 4.8 MB/s eta 0:00:00
# Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#    ---------------------------------------- 0.0/658.1 kB ? eta -:--:--
#    ------ --------------------------------- 112.6/658.1 kB 3.3 MB/s eta 0:00:01
#    ------------------- -------------------- 317.4/658.1 kB 3.9 MB/s eta 0:00:01
#    --------------------------------- ------ 553.0/658.1 kB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 658.1/658.1 kB 4.2 MB/s eta 0:00:00
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ---------------------------------------- 0.0/207.3 kB ? eta -:--:--
#    ----------------- ---------------------- 92.2/207.3 kB ? eta -:--:--
#    ---------------------------------------  204.8/207.3 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 207.3/207.3 kB 2.5 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-win_amd64.whl (25.1 MB)
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/25.1 MB 4.5 MB/s eta 0:00:06
#    ---------------------------------------- 0.3/25.1 MB 4.5 MB/s eta 0:00:06
#     --------------------------------------- 0.5/25.1 MB 4.0 MB/s eta 0:00:07
#     --------------------------------------- 0.6/25.1 MB 3.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.7/25.1 MB 3.2 MB/s eta 0:00:08
#    - -------------------------------------- 0.7/25.1 MB 2.9 MB/s eta 0:00:09
#    - -------------------------------------- 0.8/25.1 MB 2.6 MB/s eta 0:00:10
#    - -------------------------------------- 0.9/25.1 MB 2.7 MB/s eta 0:00:10
#    - -------------------------------------- 1.1/25.1 MB 2.7 MB/s eta 0:00:09
#    - -------------------------------------- 1.2/25.1 MB 2.8 MB/s eta 0:00:09
#    -- ------------------------------------- 1.3/25.1 MB 2.7 MB/s eta 0:00:09
#    -- ------------------------------------- 1.4/25.1 MB 2.7 MB/s eta 0:00:09
#    -- ------------------------------------- 1.5/25.1 MB 2.7 MB/s eta 0:00:09
#    -- ------------------------------------- 1.7/25.1 MB 2.8 MB/s eta 0:00:09
#    -- ------------------------------------- 1.9/25.1 MB 2.8 MB/s eta 0:00:09
#    --- ------------------------------------ 1.9/25.1 MB 2.7 MB/s eta 0:00:09
#    --- ------------------------------------ 2.0/25.1 MB 2.6 MB/s eta 0:00:09
#    --- ------------------------------------ 2.2/25.1 MB 2.7 MB/s eta 0:00:09
#    --- ------------------------------------ 2.3/25.1 MB 2.7 MB/s eta 0:00:09
#    --- ------------------------------------ 2.4/25.1 MB 2.6 MB/s eta 0:00:09
#    --- ------------------------------------ 2.5/25.1 MB 2.6 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.6/25.1 MB 2.6 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.7/25.1 MB 2.6 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.8/25.1 MB 2.6 MB/s eta 0:00:09
#    ---- ----------------------------------- 3.0/25.1 MB 2.6 MB/s eta 0:00:09
#    ---- ----------------------------------- 3.1/25.1 MB 2.6 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.3/25.1 MB 2.7 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.4/25.1 MB 2.7 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.4/25.1 MB 2.6 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.5/25.1 MB 2.6 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.5/25.1 MB 2.6 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.6/25.1 MB 2.5 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.7/25.1 MB 2.5 MB/s eta 0:00:09
#    ------ --------------------------------- 3.9/25.1 MB 2.5 MB/s eta 0:00:09
#    ------ --------------------------------- 4.2/25.1 MB 2.6 MB/s eta 0:00:09
#    ------ --------------------------------- 4.3/25.1 MB 2.6 MB/s eta 0:00:08
#    ------- -------------------------------- 4.5/25.1 MB 2.7 MB/s eta 0:00:08
#    ------- -------------------------------- 4.5/25.1 MB 2.7 MB/s eta 0:00:08
#    ------- -------------------------------- 4.6/25.1 MB 2.7 MB/s eta 0:00:08
#    ------- -------------------------------- 4.8/25.1 MB 2.6 MB/s eta 0:00:08
#    ------- -------------------------------- 4.9/25.1 MB 2.6 MB/s eta 0:00:08
#    ------- -------------------------------- 5.0/25.1 MB 2.6 MB/s eta 0:00:08
#    -------- ------------------------------- 5.1/25.1 MB 2.6 MB/s eta 0:00:08
#    -------- ------------------------------- 5.3/25.1 MB 2.6 MB/s eta 0:00:08
#    -------- ------------------------------- 5.3/25.1 MB 2.6 MB/s eta 0:00:08
#    -------- ------------------------------- 5.5/25.1 MB 2.6 MB/s eta 0:00:08
#    --------- ------------------------------ 5.7/25.1 MB 2.6 MB/s eta 0:00:08
#    --------- ------------------------------ 5.9/25.1 MB 2.7 MB/s eta 0:00:08
#    --------- ------------------------------ 6.0/25.1 MB 2.7 MB/s eta 0:00:08
#    --------- ------------------------------ 6.1/25.1 MB 2.7 MB/s eta 0:00:08
#    --------- ------------------------------ 6.2/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.3/25.1 MB 2.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 6.4/25.1 MB 1.7 MB/s eta 0:00:12
#    ---------- ----------------------------- 6.7/25.1 MB 1.7 MB/s eta 0:00:11
#    ---------- ----------------------------- 6.7/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.8 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.8 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.8 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.8 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.8 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.0/25.1 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.3/25.1 MB 1.4 MB/s eta 0:00:13
#    ------------ --------------------------- 7.7/25.1 MB 1.5 MB/s eta 0:00:13
#    ------------ --------------------------- 7.7/25.1 MB 1.4 MB/s eta 0:00:13
#    ------------ --------------------------- 7.9/25.1 MB 1.5 MB/s eta 0:00:12
#    ------------ --------------------------- 7.9/25.1 MB 1.5 MB/s eta 0:00:12
#    ------------ --------------------------- 8.0/25.1 MB 1.5 MB/s eta 0:00:12
#    ------------ --------------------------- 8.0/25.1 MB 1.5 MB/s eta 0:00:12
#    ------------- -------------------------- 8.8/25.1 MB 1.6 MB/s eta 0:00:11
#    -------------- ------------------------- 8.9/25.1 MB 1.6 MB/s eta 0:00:11
#    -------------- ------------------------- 9.1/25.1 MB 1.6 MB/s eta 0:00:11
#    -------------- ------------------------- 9.2/25.1 MB 1.6 MB/s eta 0:00:10
#    -------------- ------------------------- 9.4/25.1 MB 1.6 MB/s eta 0:00:10
#    --------------- ------------------------ 9.6/25.1 MB 1.7 MB/s eta 0:00:10
#    --------------- ------------------------ 9.9/25.1 MB 1.7 MB/s eta 0:00:10
#    ---------------- ----------------------- 10.1/25.1 MB 1.7 MB/s eta 0:00:09
#    ---------------- ----------------------- 10.3/25.1 MB 1.7 MB/s eta 0:00:09
#    ---------------- ----------------------- 10.6/25.1 MB 1.7 MB/s eta 0:00:09
#    ----------------- ---------------------- 10.9/25.1 MB 1.8 MB/s eta 0:00:09
#    ----------------- ---------------------- 11.0/25.1 MB 1.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 11.2/25.1 MB 1.8 MB/s eta 0:00:08
#    ------------------ --------------------- 11.4/25.1 MB 1.8 MB/s eta 0:00:08
#    ------------------ --------------------- 11.7/25.1 MB 1.8 MB/s eta 0:00:08
#    ------------------ --------------------- 11.8/25.1 MB 1.8 MB/s eta 0:00:08
#    ------------------- -------------------- 12.1/25.1 MB 1.8 MB/s eta 0:00:08
#    ------------------- -------------------- 12.3/25.1 MB 1.8 MB/s eta 0:00:07
#    -------------------- ------------------- 12.6/25.1 MB 1.9 MB/s eta 0:00:07
#    -------------------- ------------------- 12.8/25.1 MB 1.9 MB/s eta 0:00:07
#    -------------------- ------------------- 13.1/25.1 MB 1.9 MB/s eta 0:00:07
#    --------------------- ------------------ 13.3/25.1 MB 1.9 MB/s eta 0:00:07
#    --------------------- ------------------ 13.5/25.1 MB 1.9 MB/s eta 0:00:07
#    --------------------- ------------------ 13.8/25.1 MB 2.0 MB/s eta 0:00:06
#    ---------------------- ----------------- 13.9/25.1 MB 2.0 MB/s eta 0:00:06
#    ---------------------- ----------------- 14.0/25.1 MB 2.0 MB/s eta 0:00:06
#    ---------------------- ----------------- 14.0/25.1 MB 2.0 MB/s eta 0:00:06
#    ---------------------- ----------------- 14.1/25.1 MB 1.9 MB/s eta 0:00:06
#    ---------------------- ----------------- 14.3/25.1 MB 1.9 MB/s eta 0:00:06
#    ----------------------- ---------------- 14.5/25.1 MB 1.9 MB/s eta 0:00:06
#    ----------------------- ---------------- 14.6/25.1 MB 1.9 MB/s eta 0:00:06
#    ----------------------- ---------------- 14.7/25.1 MB 1.9 MB/s eta 0:00:06
#    ----------------------- ---------------- 15.0/25.1 MB 1.9 MB/s eta 0:00:06
#    ------------------------ --------------- 15.1/25.1 MB 2.0 MB/s eta 0:00:06
#    ------------------------ --------------- 15.3/25.1 MB 2.0 MB/s eta 0:00:06
#    ------------------------ --------------- 15.4/25.1 MB 2.0 MB/s eta 0:00:05
#    ------------------------ --------------- 15.5/25.1 MB 2.0 MB/s eta 0:00:05
#    ------------------------ --------------- 15.6/25.1 MB 2.0 MB/s eta 0:00:05
#    ------------------------- -------------- 15.8/25.1 MB 2.0 MB/s eta 0:00:05
#    ------------------------- -------------- 15.8/25.1 MB 2.0 MB/s eta 0:00:05
#    ------------------------- -------------- 15.8/25.1 MB 2.0 MB/s eta 0:00:05
#    ------------------------- -------------- 15.8/25.1 MB 2.0 MB/s eta 0:00:05
#    ------------------------- -------------- 15.8/25.1 MB 2.0 MB/s eta 0:00:05
#    ------------------------- -------------- 16.1/25.1 MB 1.9 MB/s eta 0:00:05
#    ------------------------- -------------- 16.3/25.1 MB 1.9 MB/s eta 0:00:05
#    -------------------------- ------------- 16.4/25.1 MB 1.9 MB/s eta 0:00:05
#    -------------------------- ------------- 16.5/25.1 MB 1.9 MB/s eta 0:00:05
#    -------------------------- ------------- 16.6/25.1 MB 2.6 MB/s eta 0:00:04
#    -------------------------- ------------- 16.8/25.1 MB 2.6 MB/s eta 0:00:04
#    -------------------------- ------------- 16.9/25.1 MB 2.6 MB/s eta 0:00:04
#    --------------------------- ------------ 17.0/25.1 MB 2.6 MB/s eta 0:00:04
#    --------------------------- ------------ 17.2/25.1 MB 2.7 MB/s eta 0:00:03
#    --------------------------- ------------ 17.3/25.1 MB 3.8 MB/s eta 0:00:03
#    --------------------------- ------------ 17.5/25.1 MB 3.7 MB/s eta 0:00:03
#    --------------------------- ------------ 17.5/25.1 MB 3.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 17.6/25.1 MB 3.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 17.8/25.1 MB 3.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 17.9/25.1 MB 3.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.0/25.1 MB 3.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.1/25.1 MB 3.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.3/25.1 MB 3.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.5/25.1 MB 3.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.6/25.1 MB 3.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.6/25.1 MB 3.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.7/25.1 MB 3.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.8/25.1 MB 3.4 MB/s eta 0:00:02
#    ------------------------------ --------- 18.9/25.1 MB 3.4 MB/s eta 0:00:02
#    ------------------------------ --------- 19.0/25.1 MB 3.3 MB/s eta 0:00:02
#    ------------------------------ --------- 19.1/25.1 MB 3.3 MB/s eta 0:00:02
#    ------------------------------ --------- 19.2/25.1 MB 3.3 MB/s eta 0:00:02
#    ------------------------------ --------- 19.4/25.1 MB 3.3 MB/s eta 0:00:02
#    ------------------------------- -------- 19.6/25.1 MB 3.3 MB/s eta 0:00:02
#    ------------------------------- -------- 19.8/25.1 MB 3.3 MB/s eta 0:00:02
#    ------------------------------- -------- 19.8/25.1 MB 3.2 MB/s eta 0:00:02
#    ------------------------------- -------- 20.0/25.1 MB 3.2 MB/s eta 0:00:02
#    -------------------------------- ------- 20.2/25.1 MB 3.2 MB/s eta 0:00:02
#    -------------------------------- ------- 20.4/25.1 MB 3.2 MB/s eta 0:00:02
#    -------------------------------- ------- 20.6/25.1 MB 3.2 MB/s eta 0:00:02
#    -------------------------------- ------- 20.7/25.1 MB 3.2 MB/s eta 0:00:02
#    --------------------------------- ------ 20.8/25.1 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 20.9/25.1 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 21.0/25.1 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 21.2/25.1 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 21.4/25.1 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.4/25.1 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.4/25.1 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.4/25.1 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.4/25.1 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.4/25.1 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.8/25.1 MB 2.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.8/25.1 MB 2.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.8/25.1 MB 2.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 22.2/25.1 MB 2.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 22.4/25.1 MB 2.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 22.5/25.1 MB 2.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 22.6/25.1 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 22.8/25.1 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 23.0/25.1 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 23.2/25.1 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 23.5/25.1 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 23.7/25.1 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 23.9/25.1 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 24.1/25.1 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 24.4/25.1 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 24.5/25.1 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  24.7/25.1 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  24.9/25.1 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  25.1/25.1 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 25.1/25.1 MB 2.9 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.2/6.9 MB 4.1 MB/s eta 0:00:02
#    -- ------------------------------------- 0.4/6.9 MB 4.7 MB/s eta 0:00:02
#    --- ------------------------------------ 0.6/6.9 MB 4.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/6.9 MB 4.3 MB/s eta 0:00:02
#    ------ --------------------------------- 1.1/6.9 MB 4.5 MB/s eta 0:00:02
#    ------- -------------------------------- 1.3/6.9 MB 4.6 MB/s eta 0:00:02
#    -------- ------------------------------- 1.5/6.9 MB 4.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.8/6.9 MB 4.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.0/6.9 MB 4.8 MB/s eta 0:00:02
#    ------------- -------------------------- 2.3/6.9 MB 4.8 MB/s eta 0:00:01
#    -------------- ------------------------- 2.5/6.9 MB 4.9 MB/s eta 0:00:01
#    --------------- ------------------------ 2.7/6.9 MB 4.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.8/6.9 MB 4.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.1/6.9 MB 4.7 MB/s eta 0:00:01
#    ------------------ --------------------- 3.3/6.9 MB 4.6 MB/s eta 0:00:01
#    -------------------- ------------------- 3.5/6.9 MB 4.7 MB/s eta 0:00:01
#    --------------------- ------------------ 3.7/6.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.0/6.9 MB 4.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.1/6.9 MB 4.7 MB/s eta 0:00:01
#    ------------------------- -------------- 4.3/6.9 MB 4.7 MB/s eta 0:00:01
#    -------------------------- ------------- 4.6/6.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.8/6.9 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.0/6.9 MB 4.7 MB/s eta 0:00:01
#    ------------------------------- -------- 5.4/6.9 MB 4.8 MB/s eta 0:00:01
#    --------------------------------- ------ 5.7/6.9 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/6.9 MB 5.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.2/6.9 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------ --- 6.4/6.9 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------- -- 6.5/6.9 MB 4.9 MB/s eta 0:00:01
#    -------------------------------------- - 6.7/6.9 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  6.9/6.9 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 4.7 MB/s eta 0:00:00
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-5.0.3-py3-none-win_amd64.whl (79 kB)
#    ---------------------------------------- 0.0/79.3 kB ? eta -:--:--
#    ---------------------------------------- 79.3/79.3 kB 4.3 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    ---------------------------------------- 62.7/62.7 kB 3.5 MB/s eta 0:00:00
# Downloading narwhals-1.9.3-py3-none-any.whl (185 kB)
#    ---------------------------------------- 0.0/185.3 kB ? eta -:--:--
#    ------------------------------ --------- 143.4/185.3 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 185.3/185.3 kB 2.8 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, toml, tenacity, smmap, pyarrow, narwhals, blinker, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-5.4.1 blinker-1.8.2 gitdb-4.0.11 gitpython-3.1.43 narwhals-1.9.3 pyarrow-17.0.0 pydeck-0.9.1 smmap-5.0.1 streamlit-1.39.0 tenacity-9.0.0 toml-0.10.2 watchdog-5.0.3

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\tien\anaconda3\envs\iod\lib\site-packages (1.39.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (5.4.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (5.4.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (13.8.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog<6,>=2.1.5 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from streamlit) (5.0.3)
# Requirement already satisfied: jinja2 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: narwhals>=1.5.2 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from altair<6,>=4.0->streamlit) (1.9.3)
# Requirement already satisfied: colorama in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\tien\anaconda3\envs\iod\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)

# %%
! streamlit hello

# %%
streamlit --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 streamlit --version
#
# NameError: name 'streamlit' is not defined

# %%
## Import Libraries
import numpy as np
import pandas as pd
import regex as re
import spacy
import streamlit as st

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.base import BaseEstimator, TransformerMixin
import joblib

# %% [markdown]
# The training data set is `sentiments.csv`, a dataset used in the NLP module.

# %%
# Read in the data
df = pd.read_csv('sentiments.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#                                                    text  sentiment  source  \
# 0                              Wow... Loved this place.          1    yelp
# 1                                    Crust is not good.          0    yelp
# 2             Not tasty and the texture was just nasty.          0    yelp
# 3     Stopped by during the late May bank holiday of...          1    yelp
# 4     The selection on the menu was great and so wer...          1    yelp
# ...                                                 ...        ...     ...
# 2995  The screen does get smudged easily because it ...          0  amazon
# 2996  What a piece of junk.. I lose more calls on th...          0  amazon
# 2997                       Item Does Not Match Picture.          0  amazon
# 2998  The only thing that disappoint me is the infra...          0  amazon
# 2999  You can not answer calls with the unit, never ...          0  amazon
#
#                                                   short
# 0                                        wow love place
# 1                                            Crust good
# 2                                   tasty texture nasty
# 3     stop late bank holiday rick steve recommendati...
# 4                            selection menu great price
# ...                                                 ...
# 2995                screen smudge easily touch ear face
# 2996                         piece junk lose call phone
# 2997                                 item match picture
# 2998               thing disappoint infra red port irda
# 2999                              answer call unit work
#
# [3000 rows x 4 columns]

# %%
df.head()
# Out:
#                                                 text  sentiment source
# 0                           Wow... Loved this place.          1   yelp
# 1                                 Crust is not good.          0   yelp
# 2          Not tasty and the texture was just nasty.          0   yelp
# 3  Stopped by during the late May bank holiday of...          1   yelp
# 4  The selection on the menu was great and so wer...          1   yelp

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text       3000 non-null   object
#  1   sentiment  3000 non-null   int64
#  2   source     3000 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 70.4+ KB

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text       3000 non-null   object
#  1   sentiment  3000 non-null   int64
#  2   source     3000 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#          sentiment
# count  3000.000000
# mean      0.500000
# std       0.500083
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000

# %%
df.isnull().sum()
# Out:
# text         0
# sentiment    0
# source       0
# dtype: int64

# %% [markdown]
# Next we define a function to do some preprocessing.

# %%
def clean_text(text):
    # reduce multiple spaces and newlines to only one
    text = re.sub(r'(\s\s+|\n\n+)', r'\1', text)
    # remove double quotes
    text = re.sub(r'"', '', text)

    return text

# %%
# Define your clean_text function
def clean_text(text):
    # Print original text (optional for debugging)
    print("Original text:", text)
    
    # reduce multiple spaces and newlines to only one
    text = re.sub(r'(\s\s+|\n\n+)', r'\1', text)
    print("After reducing spaces/newlines:", text)  # Print intermediate text
    
    # remove double quotes
    text = re.sub(r'"', '', text)
    print("After removing double quotes:", text)  # Print final cleaned text
    
    return text

# %%
df['text'] = df['text'].apply(clean_text)

# %%
df['text']
# Out:
# 0                                Wow... Loved this place.
# 1                                      Crust is not good.
# 2               Not tasty and the texture was just nasty.
# 3       Stopped by during the late May bank holiday of...
# 4       The selection on the menu was great and so wer...
#                               ...
# 2995    The screen does get smudged easily because it ...
# 2996    What a piece of junk.. I lose more calls on th...
# 2997                         Item Does Not Match Picture.
# 2998    The only thing that disappoint me is the infra...
# 2999    You can not answer calls with the unit, never ...
# Name: text, Length: 3000, dtype: object

# %% [markdown]
# The following NLP model is used for further preprocessing. The following steps are the same as used in Module 8.

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
def convert_text(text):
    sent = nlp(text)
    ents = {x.text: x for x in sent.ents}
    tokens = []
    for w in sent:
        if w.is_stop or w.is_punct:
            continue
        if w.text in ents:
            tokens.append(w.text)
        else:
            tokens.append(w.lemma_.lower())
    text = ' '.join(tokens)

    return text

# %%
df['short'] = df['text'].apply(convert_text)

# %%
# Features and Labels
X = df['short']
y = df['sentiment']

# %%
# split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 101)

# %%
classifier = LinearSVC()

# %%
# create a matrix of word counts from the text
# use TF-IDF
tfidf = TfidfVectorizer()
# do the actual counting
A = tfidf.fit_transform(X_train, y_train)

# train the classifier with the training data
classifier.fit(A.toarray(), y_train)

# do the transformation for the test data
# NOTE: use `transform()` instead of `fit_transform()`
B = tfidf.transform(X_test)

# make predictions based on the test data
predictions = classifier.predict(B)

# check the accuracy
print('Accuracy: %.4f' % accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.7733

# %% [markdown]
# We will not attempt to improve on the performance in this lab as we are more interested in how to deploy the model.

# %% [markdown]
# Next we create a pipeline to simplify the process of model creation. We first define a preprocessor class which applies the `clean_text` and `convert_text` functions defined earlier.

# %%
class preprocessor(TransformerMixin, BaseEstimator):

    def __init__(self):
        pass

    def fit(self, X, y=None):
        return self

    def transform(self, X):
         return X.apply(clean_text).apply(convert_text)

# %% [markdown]
# Next we combine the preprocessing, feature engineering and modelling steps into a single pipe.

# %%
pipe = make_pipeline(preprocessor(), tfidf, classifier)
pipe.fit(df['text'],df['sentiment'])
# Out:
# Original text: Wow... Loved this place.
# After reducing spaces/newlines: Wow... Loved this place.
# After removing double quotes: Wow... Loved this place.
# Original text: Crust is not good.
# After reducing spaces/newlines: Crust is not good.
# After removing double quotes: Crust is not good.
# Original text: Not tasty and the texture was just nasty.
# After reducing spaces/newlines: Not tasty and the texture was just nasty.
# After removing double quotes: Not tasty and the texture was just nasty.
# Original text: Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.
# After reducing spaces/newlines: Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.
# After removing double quotes: Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.
# Original text: The selection on the menu was great and so were the prices.
# After reducing spaces/newlines: The selection on the menu was great and so were the prices.
# After removing double quotes: The selection on the menu was great and so were the prices.
# Original text: Now I am getting angry and I want my damn pho.
# After reducing spaces/newlines: Now I am getting angry and I want my damn pho.
# After removing double quotes: Now I am getting angry and I want my damn pho.
# Original text: Honeslty it didn't taste THAT fresh.)
# After reducing spaces/newlines: Honeslty it didn't taste THAT fresh.)
# After removing double quotes: Honeslty it didn't taste THAT fresh.)
# Original text: The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.
# After reducing spaces/newlines: The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.
# After removing double quotes: The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.
# Original text: The fries were great too.
# After reducing spaces/newlines: The fries were great too.
# After removing double quotes: The fries were great too.
# Original text: A great touch.
# After reducing spaces/newlines: A great touch.
# After removing double quotes: A great touch.
# Original text: Service was very prompt.
# After reducing spaces/newlines: Service was very prompt.
# After removing double quotes: Service was very prompt.
# Original text: Would not go back.
# After reducing spaces/newlines: Would not go back.
# After removing double quotes: Would not go back.
# Original text: The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.
# After reducing spaces/newlines: The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.
# After removing double quotes: The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.
# Original text: I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!
# After reducing spaces/newlines: I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!
# After removing double quotes: I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!
# Original text: I was disgusted because I was pretty sure that was human hair.
# After reducing spaces/newlines: I was disgusted because I was pretty sure that was human hair.
# After removing double quotes: I was disgusted because I was pretty sure that was human hair.
# Original text: I was shocked because no signs indicate cash only.
# After reducing spaces/newlines: I was shocked because no signs indicate cash only.
# After removing double quotes: I was shocked because no signs indicate cash only.
# Original text: Highly recommended.
# After reducing spaces/newlines: Highly recommended.
# After removing double quotes: Highly recommended.
# Original text: Waitress was a little slow in service.
# After reducing spaces/newlines: Waitress was a little slow in service.
# After removing double quotes: Waitress was a little slow in service.
# Original text: This place is not worth your time, let alone Vegas.
# After reducing spaces/newlines: This place is not worth your time, let alone Vegas.
# After removing double quotes: This place is not worth your time, let alone Vegas.
# Original text: did not like at all.
# After reducing spaces/newlines: did not like at all.
# After removing double quotes: did not like at all.
# Original text: The Burrittos Blah!
# After reducing spaces/newlines: The Burrittos Blah!
# After removing double quotes: The Burrittos Blah!
# Original text: The food, amazing.
# After reducing spaces/newlines: The food, amazing.
# After removing double quotes: The food, amazing.
# Original text: Service is also cute.
# After reducing spaces/newlines: Service is also cute.
# After removing double quotes: Service is also cute.
# Original text: I could care less... The interior is just beautiful.
# After reducing spaces/newlines: I could care less... The interior is just beautiful.
# After removing double quotes: I could care less... The interior is just beautiful.
# Original text: So they performed.
# After reducing spaces/newlines: So they performed.
# After removing double quotes: So they performed.
# Original text: That's right....the red velvet cake.....ohhh this stuff is so good.
# After reducing spaces/newlines: That's right....the red velvet cake.....ohhh this stuff is so good.
# After removing double quotes: That's right....the red velvet cake.....ohhh this stuff is so good.
# Original text: - They never brought a salad we asked for.
# After reducing spaces/newlines: - They never brought a salad we asked for.
# After removing double quotes: - They never brought a salad we asked for.
# Original text: This hole in the wall has great Mexican street tacos, and friendly staff.
# After reducing spaces/newlines: This hole in the wall has great Mexican street tacos, and friendly staff.
# After removing double quotes: This hole in the wall has great Mexican street tacos, and friendly staff.
# Original text: Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed.
# After reducing spaces/newlines: Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed.
# After removing double quotes: Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed.
# Original text: The worst was the salmon sashimi.
# After reducing spaces/newlines: The worst was the salmon sashimi.
# After removing double quotes: The worst was the salmon sashimi.
# Original text: Also there are combos like a burger, fries, and beer for 23 which is a decent deal.
# After reducing spaces/newlines: Also there are combos like a burger, fries, and beer for 23 which is a decent deal.
# After removing double quotes: Also there are combos like a burger, fries, and beer for 23 which is a decent deal.
# Original text: This was like the final blow!
# After reducing spaces/newlines: This was like the final blow!
# After removing double quotes: This was like the final blow!
# Original text: I found this place by accident and I could not be happier.
# After reducing spaces/newlines: I found this place by accident and I could not be happier.
# After removing double quotes: I found this place by accident and I could not be happier.
# Original text: seems like a good quick place to grab a bite of some familiar pub food, but do yourself a favor and look elsewhere.
# After reducing spaces/newlines: seems like a good quick place to grab a bite of some familiar pub food, but do yourself a favor and look elsewhere.
# After removing double quotes: seems like a good quick place to grab a bite of some familiar pub food, but do yourself a favor and look elsewhere.
# Original text: Overall, I like this place a lot.
# After reducing spaces/newlines: Overall, I like this place a lot.
# After removing double quotes: Overall, I like this place a lot.
# Original text: The only redeeming quality of the restaurant was that it was very inexpensive.
# After reducing spaces/newlines: The only redeeming quality of the restaurant was that it was very inexpensive.
# After removing double quotes: The only redeeming quality of the restaurant was that it was very inexpensive.
# Original text: Ample portions and good prices.
# After reducing spaces/newlines: Ample portions and good prices.
# After removing double quotes: Ample portions and good prices.
# Original text: Poor service, the waiter made me feel like I was stupid every time he came to the table.
# After reducing spaces/newlines: Poor service, the waiter made me feel like I was stupid every time he came to the table.
# After removing double quotes: Poor service, the waiter made me feel like I was stupid every time he came to the table.
# Original text: My first visit to Hiro was a delight!
# After reducing spaces/newlines: My first visit to Hiro was a delight!
# After removing double quotes: My first visit to Hiro was a delight!
# Original text: Service sucks.
# After reducing spaces/newlines: Service sucks.
# After removing double quotes: Service sucks.
# Original text: The shrimp tender and moist.
# After reducing spaces/newlines: The shrimp tender and moist.
# After removing double quotes: The shrimp tender and moist.
# Original text: There is not a deal good enough that would drag me into that establishment again.
# After reducing spaces/newlines: There is not a deal good enough that would drag me into that establishment again.
# After removing double quotes: There is not a deal good enough that would drag me into that establishment again.
# Original text: Hard to judge whether these sides were good because we were grossed out by the melted styrofoam and didn't want to eat it for fear of getting sick.
# After reducing spaces/newlines: Hard to judge whether these sides were good because we were grossed out by the melted styrofoam and didn't want to eat it for fear of getting sick.
# After removing double quotes: Hard to judge whether these sides were good because we were grossed out by the melted styrofoam and didn't want to eat it for fear of getting sick.
# Original text: On a positive note, our server was very attentive and provided great service.
# After reducing spaces/newlines: On a positive note, our server was very attentive and provided great service.
# After removing double quotes: On a positive note, our server was very attentive and provided great service.
# Original text: Frozen pucks of disgust, with some of the worst people behind the register.
# After reducing spaces/newlines: Frozen pucks of disgust, with some of the worst people behind the register.
# After removing double quotes: Frozen pucks of disgust, with some of the worst people behind the register.
# Original text: The only thing I did like was the prime rib and dessert section.
# After reducing spaces/newlines: The only thing I did like was the prime rib and dessert section.
# After removing double quotes: The only thing I did like was the prime rib and dessert section.
# Original text: It's too bad the food is so damn generic.
# After reducing spaces/newlines: It's too bad the food is so damn generic.
# After removing double quotes: It's too bad the food is so damn generic.
# Original text: The burger is good beef, cooked just right.
# After reducing spaces/newlines: The burger is good beef, cooked just right.
# After removing double quotes: The burger is good beef, cooked just right.
# Original text: If you want a sandwich just go to any Firehouse!!!!!
# After reducing spaces/newlines: If you want a sandwich just go to any Firehouse!!!!!
# After removing double quotes: If you want a sandwich just go to any Firehouse!!!!!
# Original text: My side Greek salad with the Greek dressing was so tasty, and the pita and hummus was very refreshing.
# After reducing spaces/newlines: My side Greek salad with the Greek dressing was so tasty, and the pita and hummus was very refreshing.
# After removing double quotes: My side Greek salad with the Greek dressing was so tasty, and the pita and hummus was very refreshing.
# Original text: We ordered the duck rare and it was pink and tender on the inside with a nice char on the outside.
# After reducing spaces/newlines: We ordered the duck rare and it was pink and tender on the inside with a nice char on the outside.
# After removing double quotes: We ordered the duck rare and it was pink and tender on the inside with a nice char on the outside.
# Original text: He came running after us when he realized my husband had left his sunglasses on the table.
# After reducing spaces/newlines: He came running after us when he realized my husband had left his sunglasses on the table.
# After removing double quotes: He came running after us when he realized my husband had left his sunglasses on the table.
# Original text: Their chow mein is so good!
# After reducing spaces/newlines: Their chow mein is so good!
# After removing double quotes: Their chow mein is so good!
# Original text: They have horrible attitudes towards customers, and talk down to each one when customers don't enjoy their food.
# After reducing spaces/newlines: They have horrible attitudes towards customers, and talk down to each one when customers don't enjoy their food.
# After removing double quotes: They have horrible attitudes towards customers, and talk down to each one when customers don't enjoy their food.
# Original text: The portion was huge!
# After reducing spaces/newlines: The portion was huge!
# After removing double quotes: The portion was huge!
# Original text: Loved it...friendly servers, great food, wonderful and imaginative menu.
# After reducing spaces/newlines: Loved it...friendly servers, great food, wonderful and imaginative menu.
# After removing double quotes: Loved it...friendly servers, great food, wonderful and imaginative menu.
# Original text: The Heart Attack Grill in downtown Vegas is an absolutely flat-lined excuse for a restaurant.
# After reducing spaces/newlines: The Heart Attack Grill in downtown Vegas is an absolutely flat-lined excuse for a restaurant.
# After removing double quotes: The Heart Attack Grill in downtown Vegas is an absolutely flat-lined excuse for a restaurant.
# Original text: Not much seafood and like 5 strings of pasta at the bottom.
# After reducing spaces/newlines: Not much seafood and like 5 strings of pasta at the bottom.
# After removing double quotes: Not much seafood and like 5 strings of pasta at the bottom.
# Original text: The salad had just the right amount of sauce to not over power the scallop, which was perfectly cooked.
# After reducing spaces/newlines: The salad had just the right amount of sauce to not over power the scallop, which was perfectly cooked.
# After removing double quotes: The salad had just the right amount of sauce to not over power the scallop, which was perfectly cooked.
# Original text: The ripped banana was not only ripped, but petrified and tasteless.
# After reducing spaces/newlines: The ripped banana was not only ripped, but petrified and tasteless.
# After removing double quotes: The ripped banana was not only ripped, but petrified and tasteless.
# Original text: At least think to refill my water before I struggle to wave you over for 10 minutes.
# After reducing spaces/newlines: At least think to refill my water before I struggle to wave you over for 10 minutes.
# After removing double quotes: At least think to refill my water before I struggle to wave you over for 10 minutes.
# Original text: This place receives stars for their APPETIZERS!!!
# After reducing spaces/newlines: This place receives stars for their APPETIZERS!!!
# After removing double quotes: This place receives stars for their APPETIZERS!!!
# Original text: The cocktails are all handmade and delicious.
# After reducing spaces/newlines: The cocktails are all handmade and delicious.
# After removing double quotes: The cocktails are all handmade and delicious.
# Original text: We'd definitely go back here again.
# After reducing spaces/newlines: We'd definitely go back here again.
# After removing double quotes: We'd definitely go back here again.
# Original text: We are so glad we found this place.
# After reducing spaces/newlines: We are so glad we found this place.
# After removing double quotes: We are so glad we found this place.
# Original text: Great food and service, huge portions and they give a military discount.
# After reducing spaces/newlines: Great food and service, huge portions and they give a military discount.
# After removing double quotes: Great food and service, huge portions and they give a military discount.
# Original text: Always a great time at Dos Gringos!
# After reducing spaces/newlines: Always a great time at Dos Gringos!
# After removing double quotes: Always a great time at Dos Gringos!
# Original text: Update.....went back for a second time and it was still just as amazing
# After reducing spaces/newlines: Update.....went back for a second time and it was still just as amazing
# After removing double quotes: Update.....went back for a second time and it was still just as amazing
# Original text: We got the food and apparently they have never heard of salt and the batter on the fish was chewy.
# After reducing spaces/newlines: We got the food and apparently they have never heard of salt and the batter on the fish was chewy.
# After removing double quotes: We got the food and apparently they have never heard of salt and the batter on the fish was chewy.
# Original text: A great way to finish a great.
# After reducing spaces/newlines: A great way to finish a great.
# After removing double quotes: A great way to finish a great.
# Original text: The deal included 5 tastings and 2 drinks, and Jeff went above and beyond what we expected.
# After reducing spaces/newlines: The deal included 5 tastings and 2 drinks, and Jeff went above and beyond what we expected.
# After removing double quotes: The deal included 5 tastings and 2 drinks, and Jeff went above and beyond what we expected.
# Original text: - Really, really good rice, all the time.
# After reducing spaces/newlines: - Really, really good rice, all the time.
# After removing double quotes: - Really, really good rice, all the time.
# Original text: The service was meh.
# After reducing spaces/newlines: The service was meh.
# After removing double quotes: The service was meh.
# Original text: It took over 30 min to get their milkshake, which was nothing more than chocolate milk.
# After reducing spaces/newlines: It took over 30 min to get their milkshake, which was nothing more than chocolate milk.
# After removing double quotes: It took over 30 min to get their milkshake, which was nothing more than chocolate milk.
# Original text: I guess I should have known that this place would suck, because it is inside of the Excalibur, but I didn't use my common sense.
# After reducing spaces/newlines: I guess I should have known that this place would suck, because it is inside of the Excalibur, but I didn't use my common sense.
# After removing double quotes: I guess I should have known that this place would suck, because it is inside of the Excalibur, but I didn't use my common sense.
# Original text: The scallop dish is quite appalling for value as well.
# After reducing spaces/newlines: The scallop dish is quite appalling for value as well.
# After removing double quotes: The scallop dish is quite appalling for value as well.
# Original text: 2 times - Very Bad Customer Service !
# After reducing spaces/newlines: 2 times - Very Bad Customer Service !
# After removing double quotes: 2 times - Very Bad Customer Service !
# Original text: The sweet potato fries were very good and seasoned well.
# After reducing spaces/newlines: The sweet potato fries were very good and seasoned well.
# After removing double quotes: The sweet potato fries were very good and seasoned well.
# Original text: Today is the second time I've been to their lunch buffet and it was pretty good.
# After reducing spaces/newlines: Today is the second time I've been to their lunch buffet and it was pretty good.
# After removing double quotes: Today is the second time I've been to their lunch buffet and it was pretty good.
# Original text: There is so much good food in Vegas that I feel cheated for wasting an eating opportunity by going to Rice and Company.
# After reducing spaces/newlines: There is so much good food in Vegas that I feel cheated for wasting an eating opportunity by going to Rice and Company.
# After removing double quotes: There is so much good food in Vegas that I feel cheated for wasting an eating opportunity by going to Rice and Company.
# Original text: Coming here is like experiencing an underwhelming relationship where both parties can't wait for the other person to ask to break up.
# After reducing spaces/newlines: Coming here is like experiencing an underwhelming relationship where both parties can't wait for the other person to ask to break up.
# After removing double quotes: Coming here is like experiencing an underwhelming relationship where both parties can't wait for the other person to ask to break up.
# Original text: walked in and the place smelled like an old grease trap and only 2 others there eating.
# After reducing spaces/newlines: walked in and the place smelled like an old grease trap and only 2 others there eating.
# After removing double quotes: walked in and the place smelled like an old grease trap and only 2 others there eating.
# Original text: The turkey and roast beef were bland.
# After reducing spaces/newlines: The turkey and roast beef were bland.
# After removing double quotes: The turkey and roast beef were bland.
# Original text: This place has it!
# After reducing spaces/newlines: This place has it!
# After removing double quotes: This place has it!
# Original text: The pan cakes everyone are raving about taste like a sugary disaster tailored to the palate of a six year old.
# After reducing spaces/newlines: The pan cakes everyone are raving about taste like a sugary disaster tailored to the palate of a six year old.
# After removing double quotes: The pan cakes everyone are raving about taste like a sugary disaster tailored to the palate of a six year old.
# Original text: I love the Pho and the spring rolls oh so yummy you have to try.
# After reducing spaces/newlines: I love the Pho and the spring rolls oh so yummy you have to try.
# After removing double quotes: I love the Pho and the spring rolls oh so yummy you have to try.
# Original text: The poor batter to meat ratio made the chicken tenders very unsatisfying.
# After reducing spaces/newlines: The poor batter to meat ratio made the chicken tenders very unsatisfying.
# After removing double quotes: The poor batter to meat ratio made the chicken tenders very unsatisfying.
# Original text: All I have to say is the food was amazing!!!
# After reducing spaces/newlines: All I have to say is the food was amazing!!!
# After removing double quotes: All I have to say is the food was amazing!!!
# Original text: Omelets are to die for!
# After reducing spaces/newlines: Omelets are to die for!
# After removing double quotes: Omelets are to die for!
# Original text: Everything was fresh and delicious!
# After reducing spaces/newlines: Everything was fresh and delicious!
# After removing double quotes: Everything was fresh and delicious!
# Original text: In summary, this was a largely disappointing dining experience.
# After reducing spaces/newlines: In summary, this was a largely disappointing dining experience.
# After removing double quotes: In summary, this was a largely disappointing dining experience.
# Original text: It's like a really sexy party in your mouth, where you're outrageously flirting with the hottest person at the party.
# After reducing spaces/newlines: It's like a really sexy party in your mouth, where you're outrageously flirting with the hottest person at the party.
# After removing double quotes: It's like a really sexy party in your mouth, where you're outrageously flirting with the hottest person at the party.
# Original text: Never been to Hard Rock Casino before, WILL NEVER EVER STEP FORWARD IN IT AGAIN!
# After reducing spaces/newlines: Never been to Hard Rock Casino before, WILL NEVER EVER STEP FORWARD IN IT AGAIN!
# After removing double quotes: Never been to Hard Rock Casino before, WILL NEVER EVER STEP FORWARD IN IT AGAIN!
# Original text: Best breakfast buffet!!!
# After reducing spaces/newlines: Best breakfast buffet!!!
# After removing double quotes: Best breakfast buffet!!!
# Original text: say bye bye to your tip lady!
# After reducing spaces/newlines: say bye bye to your tip lady!
# After removing double quotes: say bye bye to your tip lady!
# Original text: We'll never go again.
# After reducing spaces/newlines: We'll never go again.
# After removing double quotes: We'll never go again.
# Original text: Will be back again!
# After reducing spaces/newlines: Will be back again!
# After removing double quotes: Will be back again!
# Original text: Food arrived quickly!
# After reducing spaces/newlines: Food arrived quickly!
# After removing double quotes: Food arrived quickly!
# Original text: It was not good.
# After reducing spaces/newlines: It was not good.
# After removing double quotes: It was not good.
# Original text: On the up side, their cafe serves really good food.
# After reducing spaces/newlines: On the up side, their cafe serves really good food.
# After removing double quotes: On the up side, their cafe serves really good food.
# Original text: Our server was fantastic and when he found out the wife loves roasted garlic and bone marrow, he added extra to our meal and another marrow to go!
# After reducing spaces/newlines: Our server was fantastic and when he found out the wife loves roasted garlic and bone marrow, he added extra to our meal and another marrow to go!
# After removing double quotes: Our server was fantastic and when he found out the wife loves roasted garlic and bone marrow, he added extra to our meal and another marrow to go!
# Original text: The only good thing was our waiter, he was very helpful and kept the bloddy mary's coming.
# After reducing spaces/newlines: The only good thing was our waiter, he was very helpful and kept the bloddy mary's coming.
# After removing double quotes: The only good thing was our waiter, he was very helpful and kept the bloddy mary's coming.
# Original text: Best Buffet in town, for the price you cannot beat it.
# After reducing spaces/newlines: Best Buffet in town, for the price you cannot beat it.
# After removing double quotes: Best Buffet in town, for the price you cannot beat it.
# Original text: I LOVED their mussels cooked in this wine reduction, the duck was tender, and their potato dishes were delicious.
# After reducing spaces/newlines: I LOVED their mussels cooked in this wine reduction, the duck was tender, and their potato dishes were delicious.
# After removing double quotes: I LOVED their mussels cooked in this wine reduction, the duck was tender, and their potato dishes were delicious.
# Original text: This is one of the better buffets that I have been to.
# After reducing spaces/newlines: This is one of the better buffets that I have been to.
# After removing double quotes: This is one of the better buffets that I have been to.
# Original text: So we went to Tigerlilly and had a fantastic afternoon!
# After reducing spaces/newlines: So we went to Tigerlilly and had a fantastic afternoon!
# After removing double quotes: So we went to Tigerlilly and had a fantastic afternoon!
# Original text: The food was delicious, our bartender was attentive and personable AND we got a great deal!
# After reducing spaces/newlines: The food was delicious, our bartender was attentive and personable AND we got a great deal!
# After removing double quotes: The food was delicious, our bartender was attentive and personable AND we got a great deal!
# Original text: The ambience is wonderful and there is music playing.
# After reducing spaces/newlines: The ambience is wonderful and there is music playing.
# After removing double quotes: The ambience is wonderful and there is music playing.
# Original text: Will go back next trip out.
# After reducing spaces/newlines: Will go back next trip out.
# After removing double quotes: Will go back next trip out.
# Original text: Sooooo good!!
# After reducing spaces/newlines: Sooooo good!!
# After removing double quotes: Sooooo good!!
# Original text: REAL sushi lovers, let's be honest - Yama is not that good.
# After reducing spaces/newlines: REAL sushi lovers, let's be honest - Yama is not that good.
# After removing double quotes: REAL sushi lovers, let's be honest - Yama is not that good.
# Original text: At least 40min passed in between us ordering and the food arriving, and it wasn't that busy.
# After reducing spaces/newlines: At least 40min passed in between us ordering and the food arriving, and it wasn't that busy.
# After removing double quotes: At least 40min passed in between us ordering and the food arriving, and it wasn't that busy.
# Original text: This is a really fantastic Thai restaurant which is definitely worth a visit.
# After reducing spaces/newlines: This is a really fantastic Thai restaurant which is definitely worth a visit.
# After removing double quotes: This is a really fantastic Thai restaurant which is definitely worth a visit.
# Original text: Nice, spicy and tender.
# After reducing spaces/newlines: Nice, spicy and tender.
# After removing double quotes: Nice, spicy and tender.
# Original text: Good prices.
# After reducing spaces/newlines: Good prices.
# After removing double quotes: Good prices.
# Original text: Check it out.
# After reducing spaces/newlines: Check it out.
# After removing double quotes: Check it out.
# Original text: It was pretty gross!
# After reducing spaces/newlines: It was pretty gross!
# After removing double quotes: It was pretty gross!
# Original text: I've had better atmosphere.
# After reducing spaces/newlines: I've had better atmosphere.
# After removing double quotes: I've had better atmosphere.
# Original text: Kind of hard to mess up a steak but they did.
# After reducing spaces/newlines: Kind of hard to mess up a steak but they did.
# After removing double quotes: Kind of hard to mess up a steak but they did.
# Original text: Although I very much liked the look and sound of this place, the actual experience was a bit disappointing.
# After reducing spaces/newlines: Although I very much liked the look and sound of this place, the actual experience was a bit disappointing.
# After removing double quotes: Although I very much liked the look and sound of this place, the actual experience was a bit disappointing.
# Original text: I just don't know how this place managed to served the blandest food I have ever eaten when they are preparing Indian cuisine.
# After reducing spaces/newlines: I just don't know how this place managed to served the blandest food I have ever eaten when they are preparing Indian cuisine.
# After removing double quotes: I just don't know how this place managed to served the blandest food I have ever eaten when they are preparing Indian cuisine.
# Original text: Worst service to boot, but that is the least of their worries.
# After reducing spaces/newlines: Worst service to boot, but that is the least of their worries.
# After removing double quotes: Worst service to boot, but that is the least of their worries.
# Original text: Service was fine and the waitress was friendly.
# After reducing spaces/newlines: Service was fine and the waitress was friendly.
# After removing double quotes: Service was fine and the waitress was friendly.
# Original text: The guys all had steaks, and our steak loving son who has had steak at the best and worst places said it was the best steak he's ever eaten.
# After reducing spaces/newlines: The guys all had steaks, and our steak loving son who has had steak at the best and worst places said it was the best steak he's ever eaten.
# After removing double quotes: The guys all had steaks, and our steak loving son who has had steak at the best and worst places said it was the best steak he's ever eaten.
# Original text: We thought you'd have to venture further away to get good sushi, but this place really hit the spot that night.
# After reducing spaces/newlines: We thought you'd have to venture further away to get good sushi, but this place really hit the spot that night.
# After removing double quotes: We thought you'd have to venture further away to get good sushi, but this place really hit the spot that night.
# Original text: Host staff were, for lack of a better word, BITCHES!
# After reducing spaces/newlines: Host staff were, for lack of a better word, BITCHES!
# After removing double quotes: Host staff were, for lack of a better word, BITCHES!
# Original text: Bland... Not a liking this place for a number of reasons and I don't want to waste time on bad reviewing.. I'll leave it at that...
# After reducing spaces/newlines: Bland... Not a liking this place for a number of reasons and I don't want to waste time on bad reviewing.. I'll leave it at that...
# After removing double quotes: Bland... Not a liking this place for a number of reasons and I don't want to waste time on bad reviewing.. I'll leave it at that...
# Original text: Phenomenal food, service and ambiance.
# After reducing spaces/newlines: Phenomenal food, service and ambiance.
# After removing double quotes: Phenomenal food, service and ambiance.
# Original text: I wouldn't return.
# After reducing spaces/newlines: I wouldn't return.
# After removing double quotes: I wouldn't return.
# Original text: Definitely worth venturing off the strip for the pork belly, will return next time I'm in Vegas.
# After reducing spaces/newlines: Definitely worth venturing off the strip for the pork belly, will return next time I'm in Vegas.
# After removing double quotes: Definitely worth venturing off the strip for the pork belly, will return next time I'm in Vegas.
# Original text: This place is way too overpriced for mediocre food.
# After reducing spaces/newlines: This place is way too overpriced for mediocre food.
# After removing double quotes: This place is way too overpriced for mediocre food.
# Original text: Penne vodka excellent!
# After reducing spaces/newlines: Penne vodka excellent!
# After removing double quotes: Penne vodka excellent!
# Original text: They have a good selection of food including a massive meatloaf sandwich, a crispy chicken wrap, a delish tuna melt and some tasty burgers.
# After reducing spaces/newlines: They have a good selection of food including a massive meatloaf sandwich, a crispy chicken wrap, a delish tuna melt and some tasty burgers.
# After removing double quotes: They have a good selection of food including a massive meatloaf sandwich, a crispy chicken wrap, a delish tuna melt and some tasty burgers.
# Original text: The management is rude.
# After reducing spaces/newlines: The management is rude.
# After removing double quotes: The management is rude.
# Original text: Delicious NYC bagels, good selections of cream cheese, real Lox with capers even.
# After reducing spaces/newlines: Delicious NYC bagels, good selections of cream cheese, real Lox with capers even.
# After removing double quotes: Delicious NYC bagels, good selections of cream cheese, real Lox with capers even.
# Original text: Great Subway, in fact it's so good when you come here every other Subway will not meet your expectations.
# After reducing spaces/newlines: Great Subway, in fact it's so good when you come here every other Subway will not meet your expectations.
# After removing double quotes: Great Subway, in fact it's so good when you come here every other Subway will not meet your expectations.
# Original text: I had a seriously solid breakfast here.
# After reducing spaces/newlines: I had a seriously solid breakfast here.
# After removing double quotes: I had a seriously solid breakfast here.
# Original text: This is one of the best bars with food in Vegas.
# After reducing spaces/newlines: This is one of the best bars with food in Vegas.
# After removing double quotes: This is one of the best bars with food in Vegas.
# Original text: He was extremely rude and really, there are so many other restaurants I would love to dine at during a weekend in Vegas.
# After reducing spaces/newlines: He was extremely rude and really, there are so many other restaurants I would love to dine at during a weekend in Vegas.
# After removing double quotes: He was extremely rude and really, there are so many other restaurants I would love to dine at during a weekend in Vegas.
# Original text: My drink was never empty and he made some really great menu suggestions.
# After reducing spaces/newlines: My drink was never empty and he made some really great menu suggestions.
# After removing double quotes: My drink was never empty and he made some really great menu suggestions.
# Original text: Don't do it!!!!
# After reducing spaces/newlines: Don't do it!!!!
# After removing double quotes: Don't do it!!!!
# Original text: The waiter wasn't helpful or friendly and rarely checked on us.
# After reducing spaces/newlines: The waiter wasn't helpful or friendly and rarely checked on us.
# After removing double quotes: The waiter wasn't helpful or friendly and rarely checked on us.
# Original text: My husband and I ate lunch here and were very disappointed with the food and service.
# After reducing spaces/newlines: My husband and I ate lunch here and were very disappointed with the food and service.
# After removing double quotes: My husband and I ate lunch here and were very disappointed with the food and service.
# Original text: And the red curry had so much bamboo shoots and wasn't very tasty to me.
# After reducing spaces/newlines: And the red curry had so much bamboo shoots and wasn't very tasty to me.
# After removing double quotes: And the red curry had so much bamboo shoots and wasn't very tasty to me.
# Original text: Nice blanket of moz over top but i feel like this was done to cover up the subpar food.
# After reducing spaces/newlines: Nice blanket of moz over top but i feel like this was done to cover up the subpar food.
# After removing double quotes: Nice blanket of moz over top but i feel like this was done to cover up the subpar food.
# Original text: The bathrooms are clean and the place itself is well decorated.
# After reducing spaces/newlines: The bathrooms are clean and the place itself is well decorated.
# After removing double quotes: The bathrooms are clean and the place itself is well decorated.
# Original text: The menu is always changing, food quality is going down & service is extremely slow.
# After reducing spaces/newlines: The menu is always changing, food quality is going down & service is extremely slow.
# After removing double quotes: The menu is always changing, food quality is going down & service is extremely slow.
# Original text: The service was a little slow , considering that were served by 3 people servers so the food was coming in a slow pace.
# After reducing spaces/newlines: The service was a little slow , considering that were served by 3 people servers so the food was coming in a slow pace.
# After removing double quotes: The service was a little slow , considering that were served by 3 people servers so the food was coming in a slow pace.
# Original text: I give it 2 thumbs down
# After reducing spaces/newlines: I give it 2 thumbs down
# After removing double quotes: I give it 2 thumbs down
# Original text: We watched our waiter pay a lot more attention to other tables and ignore us.
# After reducing spaces/newlines: We watched our waiter pay a lot more attention to other tables and ignore us.
# After removing double quotes: We watched our waiter pay a lot more attention to other tables and ignore us.
# Original text: My fiancé and I came in the middle of the day and we were greeted and seated right away.
# After reducing spaces/newlines: My fiancé and I came in the middle of the day and we were greeted and seated right away.
# After removing double quotes: My fiancé and I came in the middle of the day and we were greeted and seated right away.
# Original text: This is a great restaurant at the Mandalay Bay.
# After reducing spaces/newlines: This is a great restaurant at the Mandalay Bay.
# After removing double quotes: This is a great restaurant at the Mandalay Bay.
# Original text: We waited for forty five minutes in vain.
# After reducing spaces/newlines: We waited for forty five minutes in vain.
# After removing double quotes: We waited for forty five minutes in vain.
# Original text: Crostini that came with the salad was stale.
# After reducing spaces/newlines: Crostini that came with the salad was stale.
# After removing double quotes: Crostini that came with the salad was stale.
# Original text: Some highlights : Great quality nigiri here!
# After reducing spaces/newlines: Some highlights : Great quality nigiri here!
# After removing double quotes: Some highlights : Great quality nigiri here!
# Original text: the staff is friendly and the joint is always clean.
# After reducing spaces/newlines: the staff is friendly and the joint is always clean.
# After removing double quotes: the staff is friendly and the joint is always clean.
# Original text: this was a different cut than the piece the other day but still wonderful and tender s well as well flavored.
# After reducing spaces/newlines: this was a different cut than the piece the other day but still wonderful and tender s well as well flavored.
# After removing double quotes: this was a different cut than the piece the other day but still wonderful and tender s well as well flavored.
# Original text: I ordered the Voodoo pasta and it was the first time I'd had really excellent pasta since going gluten free several years ago.
# After reducing spaces/newlines: I ordered the Voodoo pasta and it was the first time I'd had really excellent pasta since going gluten free several years ago.
# After removing double quotes: I ordered the Voodoo pasta and it was the first time I'd had really excellent pasta since going gluten free several years ago.
# Original text: this place is good.
# After reducing spaces/newlines: this place is good.
# After removing double quotes: this place is good.
# Original text: Unfortunately, we must have hit the bakery on leftover day because everything we ordered was STALE.
# After reducing spaces/newlines: Unfortunately, we must have hit the bakery on leftover day because everything we ordered was STALE.
# After removing double quotes: Unfortunately, we must have hit the bakery on leftover day because everything we ordered was STALE.
# Original text: I came back today since they relocated and still not impressed.
# After reducing spaces/newlines: I came back today since they relocated and still not impressed.
# After removing double quotes: I came back today since they relocated and still not impressed.
# Original text: I was seated immediately.
# After reducing spaces/newlines: I was seated immediately.
# After removing double quotes: I was seated immediately.
# Original text: Their menu is diverse, and reasonably priced.
# After reducing spaces/newlines: Their menu is diverse, and reasonably priced.
# After removing double quotes: Their menu is diverse, and reasonably priced.
# Original text: Avoid at all cost!
# After reducing spaces/newlines: Avoid at all cost!
# After removing double quotes: Avoid at all cost!
# Original text: Restaurant is always full but never a wait.
# After reducing spaces/newlines: Restaurant is always full but never a wait.
# After removing double quotes: Restaurant is always full but never a wait.
# Original text: DELICIOUS!!
# After reducing spaces/newlines: DELICIOUS!!
# After removing double quotes: DELICIOUS!!
# Original text: This place is hands-down one of the best places to eat in the Phoenix metro area.
# After reducing spaces/newlines: This place is hands-down one of the best places to eat in the Phoenix metro area.
# After removing double quotes: This place is hands-down one of the best places to eat in the Phoenix metro area.
# Original text: So don't go there if you are looking for good food...
# After reducing spaces/newlines: So don't go there if you are looking for good food...
# After removing double quotes: So don't go there if you are looking for good food...
# Original text: I've never been treated so bad.
# After reducing spaces/newlines: I've never been treated so bad.
# After removing double quotes: I've never been treated so bad.
# Original text: Bacon is hella salty.
# After reducing spaces/newlines: Bacon is hella salty.
# After removing double quotes: Bacon is hella salty.
# Original text: We also ordered the spinach and avocado salad; the ingredients were sad and the dressing literally had zero taste.
# After reducing spaces/newlines: We also ordered the spinach and avocado salad; the ingredients were sad and the dressing literally had zero taste.
# After removing double quotes: We also ordered the spinach and avocado salad; the ingredients were sad and the dressing literally had zero taste.
# Original text: This really is how Vegas fine dining used to be, right down to the menus handed to the ladies that have no prices listed.
# After reducing spaces/newlines: This really is how Vegas fine dining used to be, right down to the menus handed to the ladies that have no prices listed.
# After removing double quotes: This really is how Vegas fine dining used to be, right down to the menus handed to the ladies that have no prices listed.
# Original text: The waitresses are very friendly.
# After reducing spaces/newlines: The waitresses are very friendly.
# After removing double quotes: The waitresses are very friendly.
# Original text: Lordy, the Khao Soi is a dish that is not to be missed for curry lovers!
# After reducing spaces/newlines: Lordy, the Khao Soi is a dish that is not to be missed for curry lovers!
# After removing double quotes: Lordy, the Khao Soi is a dish that is not to be missed for curry lovers!
# Original text: Everything on the menu is terrific and we were also thrilled that they made amazing accommodations for our vegetarian daughter.
# After reducing spaces/newlines: Everything on the menu is terrific and we were also thrilled that they made amazing accommodations for our vegetarian daughter.
# After removing double quotes: Everything on the menu is terrific and we were also thrilled that they made amazing accommodations for our vegetarian daughter.
# Original text: Perhaps I caught them on an off night judging by the other reviews, but I'm not inspired to go back.
# After reducing spaces/newlines: Perhaps I caught them on an off night judging by the other reviews, but I'm not inspired to go back.
# After removing double quotes: Perhaps I caught them on an off night judging by the other reviews, but I'm not inspired to go back.
# Original text: The service here leaves a lot to be desired.
# After reducing spaces/newlines: The service here leaves a lot to be desired.
# After removing double quotes: The service here leaves a lot to be desired.
# Original text: The atmosphere is modern and hip, while maintaining a touch of coziness.
# After reducing spaces/newlines: The atmosphere is modern and hip, while maintaining a touch of coziness.
# After removing double quotes: The atmosphere is modern and hip, while maintaining a touch of coziness.
# Original text: Not a weekly haunt, but definitely a place to come back to every once in a while.
# After reducing spaces/newlines: Not a weekly haunt, but definitely a place to come back to every once in a while.
# After removing double quotes: Not a weekly haunt, but definitely a place to come back to every once in a while.
# Original text: We literally sat there for 20 minutes with no one asking to take our order.
# After reducing spaces/newlines: We literally sat there for 20 minutes with no one asking to take our order.
# After removing double quotes: We literally sat there for 20 minutes with no one asking to take our order.
# Original text: The burger had absolutely no flavor - the meat itself was totally bland, the burger was overcooked and there was no charcoal flavor.
# After reducing spaces/newlines: The burger had absolutely no flavor - the meat itself was totally bland, the burger was overcooked and there was no charcoal flavor.
# After removing double quotes: The burger had absolutely no flavor - the meat itself was totally bland, the burger was overcooked and there was no charcoal flavor.
# ...
# After reducing spaces/newlines: You get extra minutes so that you can carry out the call and not get cut off.
# After removing double quotes: You get extra minutes so that you can carry out the call and not get cut off.
# Original text: However, after about a year, the fliptop started to get loose and wobbly and eventually my screen went black and I couldn't receive and place calls.
# After reducing spaces/newlines: However, after about a year, the fliptop started to get loose and wobbly and eventually my screen went black and I couldn't receive and place calls.
# After removing double quotes: However, after about a year, the fliptop started to get loose and wobbly and eventually my screen went black and I couldn't receive and place calls.
# Original text: I kept catching the cable on the seat and I had to pull the phone out to turn it on an off.
# After reducing spaces/newlines: I kept catching the cable on the seat and I had to pull the phone out to turn it on an off.
# After removing double quotes: I kept catching the cable on the seat and I had to pull the phone out to turn it on an off.
# Original text: The headset fulfills my requirements so I am happy with my purchase.
# After reducing spaces/newlines: The headset fulfills my requirements so I am happy with my purchase.
# After removing double quotes: The headset fulfills my requirements so I am happy with my purchase.
# Original text: Logitech Bluetooth Headset is a 10!.
# After reducing spaces/newlines: Logitech Bluetooth Headset is a 10!.
# After removing double quotes: Logitech Bluetooth Headset is a 10!.
# Original text: I like the fact that it rests lightly against your ear, rather than inside.
# After reducing spaces/newlines: I like the fact that it rests lightly against your ear, rather than inside.
# After removing double quotes: I like the fact that it rests lightly against your ear, rather than inside.
# Original text: A lot of websites have been rating this a very good phone and so do I.
# After reducing spaces/newlines: A lot of websites have been rating this a very good phone and so do I.
# After removing double quotes: A lot of websites have been rating this a very good phone and so do I.
# Original text: I have tried these cables with my computer and my iPod and it works just fine.
# After reducing spaces/newlines: I have tried these cables with my computer and my iPod and it works just fine.
# After removing double quotes: I have tried these cables with my computer and my iPod and it works just fine.
# Original text: The mic there is a joke, and the volume is quite low.
# After reducing spaces/newlines: The mic there is a joke, and the volume is quite low.
# After removing double quotes: The mic there is a joke, and the volume is quite low.
# Original text: I'm returning them.
# After reducing spaces/newlines: I'm returning them.
# After removing double quotes: I'm returning them.
# Original text: I does not maintain a connection with the computer while it is on my lap.
# After reducing spaces/newlines: I does not maintain a connection with the computer while it is on my lap.
# After removing double quotes: I does not maintain a connection with the computer while it is on my lap.
# Original text: It is easy to turn on and off when you are in the car and the volume controls are quite accessable.
# After reducing spaces/newlines: It is easy to turn on and off when you are in the car and the volume controls are quite accessable.
# After removing double quotes: It is easy to turn on and off when you are in the car and the volume controls are quite accessable.
# Original text: I have had mine for about a year and this Christmas I bought some for the rest of the family.
# After reducing spaces/newlines: I have had mine for about a year and this Christmas I bought some for the rest of the family.
# After removing double quotes: I have had mine for about a year and this Christmas I bought some for the rest of the family.
# Original text: Otherwise, easy to install and use, clear sound.
# After reducing spaces/newlines: Otherwise, easy to install and use, clear sound.
# After removing double quotes: Otherwise, easy to install and use, clear sound.
# Original text: nice leather.
# After reducing spaces/newlines: nice leather.
# After removing double quotes: nice leather.
# Original text: I had to purchase a different case.
# After reducing spaces/newlines: I had to purchase a different case.
# After removing double quotes: I had to purchase a different case.
# Original text: It is a joy to use.
# After reducing spaces/newlines: It is a joy to use.
# After removing double quotes: It is a joy to use.
# Original text: Very much disappointed with this company.
# After reducing spaces/newlines: Very much disappointed with this company.
# After removing double quotes: Very much disappointed with this company.
# Original text: Very satisifed with that.
# After reducing spaces/newlines: Very satisifed with that.
# After removing double quotes: Very satisifed with that.
# Original text: It didn't charge for me.
# After reducing spaces/newlines: It didn't charge for me.
# After removing double quotes: It didn't charge for me.
# Original text: This is the phone to get for 2005.... I just bought my S710a and all I can say is WOW!
# After reducing spaces/newlines: This is the phone to get for 2005.... I just bought my S710a and all I can say is WOW!
# After removing double quotes: This is the phone to get for 2005.... I just bought my S710a and all I can say is WOW!
# Original text: Buttons are too small.
# After reducing spaces/newlines: Buttons are too small.
# After removing double quotes: Buttons are too small.
# Original text: Just reading on the specs alone makes you say WOW.
# After reducing spaces/newlines: Just reading on the specs alone makes you say WOW.
# After removing double quotes: Just reading on the specs alone makes you say WOW.
# Original text: Love it.. Great armband.
# After reducing spaces/newlines: Love it.. Great armband.
# After removing double quotes: Love it.. Great armband.
# Original text: I really like this product over the Motorola because it is allot clearer on the ear piece and the mic.
# After reducing spaces/newlines: I really like this product over the Motorola because it is allot clearer on the ear piece and the mic.
# After removing double quotes: I really like this product over the Motorola because it is allot clearer on the ear piece and the mic.
# Original text: However, the keypads are so tinny that I sometimes reach the wrong buttons.
# After reducing spaces/newlines: However, the keypads are so tinny that I sometimes reach the wrong buttons.
# After removing double quotes: However, the keypads are so tinny that I sometimes reach the wrong buttons.
# Original text: I exchanged the sony ericson z500a for this and I'm pretty happy with that decision.
# After reducing spaces/newlines: I exchanged the sony ericson z500a for this and I'm pretty happy with that decision.
# After removing double quotes: I exchanged the sony ericson z500a for this and I'm pretty happy with that decision.
# Original text: I was very impressed with the price of the cases.
# After reducing spaces/newlines: I was very impressed with the price of the cases.
# After removing double quotes: I was very impressed with the price of the cases.
# Original text: Also makes it easier to hold on to.
# After reducing spaces/newlines: Also makes it easier to hold on to.
# After removing double quotes: Also makes it easier to hold on to.
# Original text: I use this product in a motor control center where there is a lot of high voltage humming from the equipment, and it works great!
# After reducing spaces/newlines: I use this product in a motor control center where there is a lot of high voltage humming from the equipment, and it works great!
# After removing double quotes: I use this product in a motor control center where there is a lot of high voltage humming from the equipment, and it works great!
# Original text: It's pretty easy.
# After reducing spaces/newlines: It's pretty easy.
# After removing double quotes: It's pretty easy.
# Original text: I cannot make calls at certain places.
# After reducing spaces/newlines: I cannot make calls at certain places.
# After removing double quotes: I cannot make calls at certain places.
# Original text: however, my girl was complain that some time the phone doesn't wake up like normal phone does.
# After reducing spaces/newlines: however, my girl was complain that some time the phone doesn't wake up like normal phone does.
# After removing double quotes: however, my girl was complain that some time the phone doesn't wake up like normal phone does.
# Original text: Beautiful styling though.
# After reducing spaces/newlines: Beautiful styling though.
# After removing double quotes: Beautiful styling though.
# Original text: This company charge me a restocking fee and still not given me my refund back.
# After reducing spaces/newlines: This company charge me a restocking fee and still not given me my refund back.
# After removing double quotes: This company charge me a restocking fee and still not given me my refund back.
# Original text: I'm trying to return it for a refund.
# After reducing spaces/newlines: I'm trying to return it for a refund.
# After removing double quotes: I'm trying to return it for a refund.
# Original text: I plugged it in only to find out not a darn thing worked.
# After reducing spaces/newlines: I plugged it in only to find out not a darn thing worked.
# After removing double quotes: I plugged it in only to find out not a darn thing worked.
# Original text: Excellent product.
# After reducing spaces/newlines: Excellent product.
# After removing double quotes: Excellent product.
# Original text: Earbud piece breaks easily.
# After reducing spaces/newlines: Earbud piece breaks easily.
# After removing double quotes: Earbud piece breaks easily.
# Original text: Lousy product.
# After reducing spaces/newlines: Lousy product.
# After removing double quotes: Lousy product.
# Original text: This phone tries very hard to do everything but fails at it's very ability to be a phone.
# After reducing spaces/newlines: This phone tries very hard to do everything but fails at it's very ability to be a phone.
# After removing double quotes: This phone tries very hard to do everything but fails at it's very ability to be a phone.
# Original text: It is the best charger I have seen on the market yet.
# After reducing spaces/newlines: It is the best charger I have seen on the market yet.
# After removing double quotes: It is the best charger I have seen on the market yet.
# Original text: SWEETEST PHONE!!!
# After reducing spaces/newlines: SWEETEST PHONE!!!
# After removing double quotes: SWEETEST PHONE!!!
# Original text: :-)Oh, the charger seems to work fine.
# After reducing spaces/newlines: :-)Oh, the charger seems to work fine.
# After removing double quotes: :-)Oh, the charger seems to work fine.
# Original text: It fits so securely that the ear hook does not even need to be used and the sound is better directed through your ear canal.
# After reducing spaces/newlines: It fits so securely that the ear hook does not even need to be used and the sound is better directed through your ear canal.
# After removing double quotes: It fits so securely that the ear hook does not even need to be used and the sound is better directed through your ear canal.
# Original text: Not enough volume.
# After reducing spaces/newlines: Not enough volume.
# After removing double quotes: Not enough volume.
# Original text: Echo Problem....Very unsatisfactory
# After reducing spaces/newlines: Echo Problem....Very unsatisfactory
# After removing double quotes: Echo Problem....Very unsatisfactory
# Original text: you could only take 2 videos at a time and the quality was very poor.
# After reducing spaces/newlines: you could only take 2 videos at a time and the quality was very poor.
# After removing double quotes: you could only take 2 videos at a time and the quality was very poor.
# Original text: don't waste your money.
# After reducing spaces/newlines: don't waste your money.
# After removing double quotes: don't waste your money.
# Original text: I am going to have to be the first to negatively review this product.
# After reducing spaces/newlines: I am going to have to be the first to negatively review this product.
# After removing double quotes: I am going to have to be the first to negatively review this product.
# Original text: Adapter does not provide enough charging current.
# After reducing spaces/newlines: Adapter does not provide enough charging current.
# After removing double quotes: Adapter does not provide enough charging current.
# Original text: There was so much hype over this phone that I assumed it was the best, my mistake.
# After reducing spaces/newlines: There was so much hype over this phone that I assumed it was the best, my mistake.
# After removing double quotes: There was so much hype over this phone that I assumed it was the best, my mistake.
# Original text: You also cannot take pictures with it in the case because the lense is covered.
# After reducing spaces/newlines: You also cannot take pictures with it in the case because the lense is covered.
# After removing double quotes: You also cannot take pictures with it in the case because the lense is covered.
# Original text: Phone falls out easily.
# After reducing spaces/newlines: Phone falls out easily.
# After removing double quotes: Phone falls out easily.
# Original text: It didn't work, people can not hear me when I talk.
# After reducing spaces/newlines: It didn't work, people can not hear me when I talk.
# After removing double quotes: It didn't work, people can not hear me when I talk.
# Original text: The text messaging feature is really tricky to use.
# After reducing spaces/newlines: The text messaging feature is really tricky to use.
# After removing double quotes: The text messaging feature is really tricky to use.
# Original text: I'm really disappointed all I have now is a charger that doesn't work.
# After reducing spaces/newlines: I'm really disappointed all I have now is a charger that doesn't work.
# After removing double quotes: I'm really disappointed all I have now is a charger that doesn't work.
# Original text: Painful on the ear.
# After reducing spaces/newlines: Painful on the ear.
# After removing double quotes: Painful on the ear.
# Original text: Lasted one day and then blew up.
# After reducing spaces/newlines: Lasted one day and then blew up.
# After removing double quotes: Lasted one day and then blew up.
# Original text: disappointed.
# After reducing spaces/newlines: disappointed.
# After removing double quotes: disappointed.
# Original text: Kind of flops around.
# After reducing spaces/newlines: Kind of flops around.
# After removing double quotes: Kind of flops around.
# Original text: The screen does get smudged easily because it touches your ear and face.
# After reducing spaces/newlines: The screen does get smudged easily because it touches your ear and face.
# After removing double quotes: The screen does get smudged easily because it touches your ear and face.
# Original text: What a piece of junk.. I lose more calls on this phone.
# After reducing spaces/newlines: What a piece of junk.. I lose more calls on this phone.
# After removing double quotes: What a piece of junk.. I lose more calls on this phone.
# Original text: Item Does Not Match Picture.
# After reducing spaces/newlines: Item Does Not Match Picture.
# After removing double quotes: Item Does Not Match Picture.
# Original text: The only thing that disappoint me is the infra red port (irda).
# After reducing spaces/newlines: The only thing that disappoint me is the infra red port (irda).
# After removing double quotes: The only thing that disappoint me is the infra red port (irda).
# Original text: You can not answer calls with the unit, never worked once!
# After reducing spaces/newlines: You can not answer calls with the unit, never worked once!
# After removing double quotes: You can not answer calls with the unit, never worked once!
# Pipeline(steps=[('preprocessor', preprocessor()),
#                 ('tfidfvectorizer', TfidfVectorizer()),
#                 ('linearsvc', LinearSVC())])

# %%
# Save the model
joblib.dump(pipe, 'model.joblib')
# Out:
# ['model.joblib']

# %% [markdown]
# **Exercise**: test the resulting model on phrases of positive and negative sentiment.

# %%
pipe.predict(pd.Series("lightweight and works well"))[0]
# Out:
# Original text: lightweight and works well
# After reducing spaces/newlines: lightweight and works well
# After removing double quotes: lightweight and works well
# 1

# %%
# Positive examples
positive_phrases = [
    "I love this product, it's amazing!",
    "The movie was fantastic, I highly recommend it.",
    "Great customer service and fast delivery.",
    "This is the best experience I've ever had.",
    "The food at the restaurant was delicious."]

# %%
# Negative examples
negative_phrases = [
    "This is the worst product I've ever bought.",
    "The movie was terrible, don't waste your time.",
    "Poor customer service and slow shipping.",
    "I had a horrible experience and wouldn't go back.",
    "The food was cold and tasteless."]

# %%
# Custom test
custom_phrases = [
    "The product arrived on time but was damaged.",
    "Despite the rain, we had a great time at the park.",
    "The phone's battery life is disappointing, but the camera is excellent."
]

print("Custom phrases:")
for phrase in custom_phrases:
    print(f"Text: '{phrase}'")
    print(f"Predicted sentiment: {predict_sentiment(phrase)}\n")
# Out:
# Custom phrases:
# Text: 'The product arrived on time but was damaged.'
# Original text: The product arrived on time but was damaged.
# After reducing spaces/newlines: The product arrived on time but was damaged.
# After removing double quotes: The product arrived on time but was damaged.
# Predicted sentiment: Negative
#
# Text: 'Despite the rain, we had a great time at the park.'
# Original text: Despite the rain, we had a great time at the park.
# After reducing spaces/newlines: Despite the rain, we had a great time at the park.
# After removing double quotes: Despite the rain, we had a great time at the park.
# Predicted sentiment: Positive
#
# Text: 'The phone's battery life is disappointing, but the camera is excellent.'
# Original text: The phone's battery life is disappointing, but the camera is excellent.
# After reducing spaces/newlines: The phone's battery life is disappointing, but the camera is excellent.
# After removing double quotes: The phone's battery life is disappointing, but the camera is excellent.
# Predicted sentiment: Positive

# %%
# Function to predict sentiment
def predict_sentiment(text):
    prediction = model.predict(pd.Series(text))[0]
    return "Positive" if prediction == 1 else "Negative"

# %%
# Load the saved model
model = joblib.load('model.joblib')

# %% [markdown]
# Once satisfied that we have a model ready for deployment, we can write a self-contained script that creates the model and saves it as a joblib file. By doing so from a script rather than the notebook we simplify the process when deploying.

# %% [markdown]
# **Exercise**:
# 1. Review the code in model.py.
# 2. Open an Anaconda prompt (Windows) or Terminal window (Mac).
# 3. Navigate to the folder where model.py is located using the command `cd "<path to your folder>"`.
# 4. At the prompt enter `python model.py`. After a few moments this creates a file `model.joblib`.

# %% [markdown]
# Let us load this model and verify that it alone can be used to make predictions.

# %%
newpipe = joblib.load(open('model.joblib','rb'))

# %%
type(newpipe)
# Out:
# sklearn.pipeline.Pipeline

# %% [markdown]
# Testing this out:

# %%
print(newpipe.predict(pd.Series('awesome place'))[0])
print(newpipe.predict(pd.Series('terrible!'))[0])
print(newpipe.predict(pd.Series('very interesting'))[0])
# Out:
# Original text: awesome place
# After reducing spaces/newlines: awesome place
# After removing double quotes: awesome place
# 1
# Original text: terrible!
# After reducing spaces/newlines: terrible!
# After removing double quotes: terrible!
# 0
# Original text: very interesting
# After reducing spaces/newlines: very interesting
# After removing double quotes: very interesting
# 1

# %% [markdown]
# We can then write a self-contained script that loads the model and can make predictions on the fly. This is partially done for you in the file "app.py".

# %% [markdown]
# **Exercise**: Refer to app.py and fill in the missing code based on the code above using a text editor such as Spyder or even Jupyter. Observe how it links to utils.py which contains the preprocessing functions.

# %% [markdown]
# ### Local hosting

# %% [markdown]
# Using Anaconda prompt (Windows) or a Terminal window (Mac) run "streamlit run app.py". This deploys the app locally on http://localhost:8501/ (or similar) which you can then view on the browser. The file app.py may require debugging before it runs successfully.

# %% [markdown]
# **Bonus Exercise**: Redesign the webpage by adding other components. You can use the cheat sheet at https://docs.streamlit.io/library/cheatsheet as a reference.

# %% [markdown]
# ### Deployment via streamlit.io

# %% [markdown]
# So far you have deployed your model on your local machine. Now we seek to deploy it publicly.

# %% [markdown]
# streamlit.io is intended to deploy Streamlit apps seamlessly without worrying about infrastructure.

# %% [markdown]
# There is one additional file needed for external deployment of your model:
# - requirements.txt includes the versions of packages that are to be used with the app.

# %% [markdown]
# To update the `requirements.txt` file use the `__version__` attribute to see the version of packages being used. This ensures that your model is reproducible on other computing environments.

# %%
joblib.__version__

# %%
st.__version__

# %% [markdown]
# Log into your GitHub account (create one if you have not already done so) and create a new repository containing the following files.

# %% [markdown]
# - requirements.txt
# - app.py
# - model.joblib
# - utils.py
# - .streamlit/ (folder containing config.toml)
#
# This config.toml allows one to set themes such as the type of background to display.

# %% [markdown]
# Next sign up for a free account at https://streamlit.io/ and once signed in, go to https://share.streamlit.io/ and click the blue "New app" button. Under "Repository" specify the GitHub repository where your app is located (in the form username/reponame). The default URL is based on the app's location in GitHub, but that may be changed. Under "main file path" enter `app.py` replacing `streamlit-app.py`. Finally click the "Deploy!" button. If successful the app will deployed to the specified url (it may take several minutes). An example can be seen at https://iod-sentiment-app.streamlit.app/.
#
# If there are issues, click on the "Manage app" button at the bottom right to view the app's logs. Files such as requirements.txt can be edited directly within GitHub.
#
# Further details are at https://docs.streamlit.io/streamlit-community-cloud/manage-your-app.

# %% [markdown]
# If you managed to see your app successfully, congratulations! You now know how to deploy an app on the cloud. To make it visible to others, go to your app's settings and under "Sharing" -> "Who can view this app" select "This app is public and searchable".

# %% [markdown]
# ### Deployment via render.com (optional)

# %% [markdown]
# Render is a general-purpose cloud platform that goes beyond deploying streamlit apps. It can host a broader range of web applications, APIs, databases and more.

# %% [markdown]
# Sign up for a free account at https://dashboard.render.com/register (a Platform As A Service) by connecting via your GitHub account.

# %% [markdown]
# Once signed into dashboard.render.com click "New Web Service" under Web Services.
#
# From "connect GitHub account", select the repository containing the above files.
#
# Choose a unique name for the web service and leave the root directory blank. Under "start command" enter `streamlit run app.py`.
#
# Finally click "Create Web Service". It may take a few minutes to work but
# upon seeing "Booting worker with pid:" go to the url specified. An example can be seen at https://streamlit-sentiment.onrender.com/

# %% [markdown]
# Note that if working in part of a larger software system it is good practice to have versioning of code (e.g. with GitHub) and also make use of CI/CD software.

# %% [markdown]
# ### References

# %% [markdown]
# More information on pipelines:
# - https://gist.github.com/amberjrivera/8c5c145516f5a2e894681e16a8095b5c
# - https://scikit-learn.org/stable/modules/compose.html#pipeline
#
# Deploying Streamlit apps on Render and Streamlit Cloud:
# - https://www.youtube.com/watch?v=bXRVgg2iWyc

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2024 Institute of Data
#
#
# ---
#
#
#
# ---
