# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 6.4
# # *PCA Lab*
#
# **In this lab, we will:**
# - Explore how PCA is related to correlation.
# - Use PCA to perform dimensionality reduction.

# %% [markdown]
# ### 1. Load Data
#
# Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image. n the 3-dimensional space is that described in: [K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server: ftp ftp.cs.wisc.edu cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# Also can be found on UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29
#
# Attribute Information:
#
# 1) ID number 2) Diagnosis (M = malignant, B = benign) 3-32)
#
# Ten real-valued features are computed for each cell nucleus:
#
# a) radius (mean of distances from center to points on the perimeter) b) texture (standard deviation of gray-scale values) c) perimeter d) area e) smoothness (local variation in radius lengths) f) compactness (perimeter^2 / area - 1.0) g) concavity (severity of concave portions of the contour) h) concave points (number of concave portions of the contour) i) symmetry j) fractal dimension ("coastline approximation" - 1)
#
# The mean, standard error and "worst" or largest (mean of the three largest values) of these features were computed for each image, resulting in 30 features. For instance, field 3 is Mean Radius, field 13 is Radius SE, field 23 is Worst Radius.
#
# All feature values are recoded with four significant digits.
#
# Missing attribute values: none
#
# Class distribution: 357 benign, 212 malignant

# %%
# IMPORT LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
breast_cancer_csv = 'breast-cancer-wisconsin-data.csv'
df = pd.read_csv(breast_cancer_csv)

# %% [markdown]
# ### 2. EDA
#
# Explore dataset. Clean data. Find correlation.

# %%
print(df.head())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# Display summary statistics
print(df.describe())
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# Drop the 'Unnamed: 32' column
df = df.drop('Unnamed: 32', axis=1, errors='ignore')

# %%
# Calculate and plot correlation matrix
corr_matrix = df.drop(['id', 'diagnosis'], axis=1).corr()
plt.figure(figsize=(20, 16))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Breast Cancer Features')
plt.show()

# %% [markdown]
# ### 3. Subset & Normalize
#
# Subset the data to only include all columns except diagnosis.

# %%
# ANSWER
# Separate features and target
X = df.drop(['id', 'diagnosis'], axis=1)
y = df['diagnosis']

# Convert target to numeric (0 for benign, 1 for malignant)
y = (y == 'M').astype(int)

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Calculate correlation matrix
#
# We will be using the correlation matrix to calculate the eigenvectors and eigenvalues.

# %%
# ANSWER
correlation_matrix = np.corrcoef(X_scaled.T)

# %% [markdown]
# ### 4. Calculate the eigenvalues and eigenvectors from the correlation matrix
#
# numpy has a convenient function to calculate this:
#
#     eigenvalues, eigenvectors = np.linalg.eig(correlation_matrix)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %% [raw]
# # Drop the 'Unnamed: 32' column
# df = df.drop('Unnamed: 32', axis=1, errors='ignore')

# %%
# ANSWER
eigenvalues, eigenvectors = np.linalg.eig(correlation_matrix)

# Sort eigenvalues and eigenvectors in descending order
idx = eigenvalues.argsort()[::-1]
eigenvalues = eigenvalues[idx]
eigenvectors = eigenvectors[:, idx]

# %%
# Check for any NaN or inf values in the correlation matrix
print("NaN values in correlation matrix:", np.isnan(correlation_matrix).any())
print("Inf values in correlation matrix:", np.isinf(correlation_matrix).any())

# Check if the correlation matrix is positive semi-definite
eigenvalues_check = np.linalg.eigvals(correlation_matrix)
print("Minimum eigenvalue:", np.min(eigenvalues_check))
print("Maximum eigenvalue:", np.max(eigenvalues_check))

# Print the correlation matrix
print("\nCorrelation matrix:")
print(correlation_matrix)
# Out:
# NaN values in correlation matrix: False
# Inf values in correlation matrix: False
# Minimum eigenvalue: 0.000133044822821758
# Maximum eigenvalue: 13.281607682257906
#
# Correlation matrix:
# [[ 1.00000000e+00  3.23781891e-01  9.97855281e-01  9.87357170e-01
#    1.70581187e-01  5.06123578e-01  6.76763550e-01  8.22528522e-01
#    1.47741242e-01 -3.11630826e-01  6.79090388e-01 -9.73174431e-02
#    6.74171616e-01  7.35863663e-01 -2.22600125e-01  2.05999980e-01
#    1.94203623e-01  3.76168956e-01 -1.04320881e-01 -4.26412691e-02
#    9.69538973e-01  2.97007644e-01  9.65136514e-01  9.41082460e-01
#    1.19616140e-01  4.13462823e-01  5.26911462e-01  7.44214198e-01
#    1.63953335e-01  7.06588569e-03]
#  [ 3.23781891e-01  1.00000000e+00  3.29533059e-01  3.21085696e-01
#   -2.33885160e-02  2.36702222e-01  3.02417828e-01  2.93464051e-01
#    7.14009805e-02 -7.64371834e-02  2.75868676e-01  3.86357623e-01
#    2.81673115e-01  2.59844987e-01  6.61377735e-03  1.91974611e-01
# ...

# %%
# Convert target to numeric (0 for benign, 1 for malignant)
y = (y == 'M').astype(int)

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Calculate correlation matrix
correlation_matrix = np.corrcoef(X_scaled.T)

# Calculate eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(correlation_matrix)

# Sort eigenvalues and eigenvectors in descending order
idx = eigenvalues.argsort()[::-1]
eigenvalues = eigenvalues[idx]
eigenvectors = eigenvectors[:, idx]

print("Shape of X:", X.shape)
print("Shape of correlation matrix:", correlation_matrix.shape)
print("Number of eigenvalues:", len(eigenvalues))
print("Shape of eigenvectors:", eigenvectors.shape)

# %%
# Remove constant columns
X_scaled_clean = X_scaled[:, np.std(X_scaled, axis=0) != 0]

# Recalculate the correlation matrix
correlation_matrix = np.corrcoef(X_scaled_clean.T)

# If there are still issues, we can use a more robust method
if np.isnan(correlation_matrix).any() or np.isinf(correlation_matrix).any():
    print("Using a more robust correlation method...")
    correlation_matrix = np.array([[1 if i == j else 0 for i in range(X_scaled_clean.shape[1])] for j in range(X_scaled_clean.shape[1])])
    for i in range(X_scaled_clean.shape[1]):
        for j in range(i+1, X_scaled_clean.shape[1]):
            valid = ~(np.isnan(X_scaled_clean[:, i]) | np.isnan(X_scaled_clean[:, j]))
            if np.sum(valid) > 1:
                correlation_matrix[i, j] = correlation_matrix[j, i] = np.corrcoef(X_scaled_clean[valid, i], X_scaled_clean[valid, j])[0, 1]

# Now try to calculate eigenvalues and eigenvectors
try:
    eigenvalues, eigenvectors = np.linalg.eig(correlation_matrix)
    print("Successfully calculated eigenvalues and eigenvectors")
except np.linalg.LinAlgError as e:
    print(f"Error calculating eigenvalues and eigenvectors: {e}")
    # If there's still an error, we might need to use a different method or investigate the data further

# Sort eigenvalues and eigenvectors in descending order
idx = eigenvalues.argsort()[::-1]
eigenvalues = eigenvalues[idx]
eigenvectors = eigenvectors[:, idx]

print("Eigenvalues:", eigenvalues)
print("Shape of eigenvectors:", eigenvectors.shape)

# %%
# Check for any constant columns in the original data
constant_columns = X.columns[X.std() == 0]
print("Constant columns:", constant_columns)

# Check for any columns with NaN or inf values
problematic_columns = X.columns[X.isna().any() | np.isinf(X).any()]
print("Columns with NaN or inf values:", problematic_columns)

# If there are problematic columns, remove them and restart the process
if len(constant_columns) > 0 or len(problematic_columns) > 0:
    X_clean = X.drop(columns=list(constant_columns) + list(problematic_columns))
    print("Shape of cleaned data:", X_clean.shape)
    
    # Normalize the cleaned data
    scaler = StandardScaler()
    X_scaled_clean = scaler.fit_transform(X_clean)
    
    # Recalculate correlation matrix
    correlation_matrix = np.corrcoef(X_scaled_clean.T)
    
    # Try to calculate eigenvalues and eigenvectors again
    eigenvalues, eigenvectors = np.linalg.eig(correlation_matrix)
    
    # Sort eigenvalues and eigenvectors in descending order
    idx = eigenvalues.argsort()[::-1]
    eigenvalues = eigenvalues[idx]
    eigenvectors = eigenvectors[:, idx]
    
    print("Successfully calculated eigenvalues and eigenvectors")
    print("Eigenvalues:", eigenvalues)
    print("Shape of eigenvectors:", eigenvectors.shape)
    print("Eigenvectors:", eigenvectors)
# Out:
# Constant columns: Index([], dtype='object')
# Columns with NaN or inf values: Index(['Unnamed: 32'], dtype='object')
# Shape of cleaned data: (569, 30)
# Successfully calculated eigenvalues and eigenvectors
# Eigenvalues: [1.32816077e+01 5.69135461e+00 2.81794898e+00 1.98064047e+00
#  1.64873055e+00 1.20735661e+00 6.75220114e-01 4.76617140e-01
#  4.16894812e-01 3.50693457e-01 2.93915696e-01 2.61161370e-01
#  2.41357496e-01 1.57009724e-01 9.41349650e-02 7.98628010e-02
#  5.93990378e-02 5.26187835e-02 4.94775918e-02 3.11594025e-02
#  2.99728939e-02 2.74394025e-02 2.43408378e-02 1.80550070e-02
#  1.54812714e-02 8.17763986e-03 6.90046388e-03 1.58933787e-03
#  7.48803097e-04 1.33044823e-04]
# Shape of eigenvectors: (30, 30)
# Eigenvectors: [[ 2.18902444e-01 -2.33857132e-01 -8.53124284e-03  4.14089623e-02
#   -3.77863538e-02  1.87407904e-02  1.24088340e-01  7.45229622e-03
#   -2.23109764e-01  9.54864432e-02  4.14714866e-02  5.10674568e-02
# ...

# %% [markdown]
# ### 5. Calculate and plot the explained variance
#
# A useful measure is the **explained variance**, which is calculated from the eigenvalues.
#
# The explained variance tells us how much information (variance) is captured by each principal component.
#
# ### $$ ExpVar_i = \bigg(\frac{eigenvalue_i}{\sum_j^n{eigenvalue_j}}\bigg) * 100$$

# %%
def calculate_cum_var_exp(eig_vals):
    '''
    Calculate Explained Variance from Eigenvalues

    Return a list or array containing the cumulative explained variance
    '''
    # Ensure the eigenvalues are sorted in descending order
    sorted_eig_vals = sorted(eig_vals, reverse=True)
    
    # Calculate the total variance
    total_variance = sum(sorted_eig_vals)
    
    # Calculate the proportion of variance explained by each eigenvalue
    var_exp = [val / total_variance for val in sorted_eig_vals]
    
    # Calculate the cumulative explained variance
    cum_var_exp = np.cumsum(var_exp)
    
    # Convert to percentages
    cum_var_exp_percent = cum_var_exp * 100

    return cum_var_exp_percent
    # Calculate the cumulative explained variance
cum_var_exp = calculate_cum_var_exp(eigenvalues)

# %%
def plot_var_exp(eig_vals):

    cum_var_exp = calculate_cum_var_exp(eig_vals)

    plt.figure(figsize=(9,7))

    component_number = [i+1 for i in range(len(cum_var_exp))]

    plt.plot(component_number, cum_var_exp, lw=7)

    plt.axhline(y=0, linewidth=5, color='grey', ls='dashed')
    plt.axhline(y=100, linewidth=3, color='grey', ls='dashed')

    ax = plt.gca()
    ax.set_xlim([1,30])
    ax.set_ylim([-5,105])

    ax.set_ylabel('cumulative variance explained', fontsize=16)
    ax.set_xlabel('component', fontsize=16)

    for tick in ax.xaxis.get_major_ticks():
        tick.label1.set_fontsize(12)

    for tick in ax.yaxis.get_major_ticks():
        tick.label1.set_fontsize(12)

    ax.set_title('component vs cumulative variance explained\n', fontsize=20)

    plt.show()

# %%
def plot_var_exp(eig_vals):
    cum_var_exp = calculate_cum_var_exp(eig_vals)
    plt.figure(figsize=(9,7))
    component_number = [i+1 for i in range(len(cum_var_exp))]
    plt.plot(component_number, cum_var_exp, lw=7)
    plt.axhline(y=0, linewidth=5, color='grey', ls='dashed')
    plt.axhline(y=100, linewidth=3, color='grey', ls='dashed')
    ax = plt.gca()
    ax.set_xlim([1,30])
    ax.set_ylim([-5,105])
    ax.set_ylabel('cumulative variance explained', fontsize=16)
    ax.set_xlabel('component', fontsize=16)
    for tick in ax.xaxis.get_major_ticks():
        tick.label1.set_fontsize(12)
    for tick in ax.yaxis.get_major_ticks():
        tick.label1.set_fontsize(12)
    ax.set_title('component vs cumulative variance explained\n', fontsize=20)
    plt.show()

# Assuming we have already calculated the eigenvalues
plot_var_exp(eigenvalues)

# Print the number of components needed to explain 95% of the variance
cum_var_exp = calculate_cum_var_exp(eigenvalues)
n_components_95 = next(i for i, var in enumerate(cum_var_exp) if var >= 95) + 1
print(f"Number of components needed to explain 95% of variance: {n_components_95}")
# Out:
# Number of components needed to explain 95% of variance: 10

# %%
# Plot the cumulative explained variance
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(cum_var_exp) + 1), cum_var_exp, 'bo-')
plt.title('Cumulative Explained Variance vs. Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance (%)')
plt.grid(True)
plt.show()

# Print the number of components needed to explain 95% of the variance
n_components_95 = next(i for i, var in enumerate(cum_var_exp) if var >= 95) + 1
print(f"Number of components needed to explain 95% of variance: {n_components_95}")
# Out:
# Number of components needed to explain 95% of variance: 10

# %% [markdown]
# ### 6. Using sklearn For PCA
#
#     from sklearn.decomposition import PCA
#
# - Create an instance of PCA
# - Fit X
# - Plot the explained variance
# - Define n_components
#     - n_component
# - Apply dimensionality reduction to X
#     - transform
# - Create PairPlot of PCA

# %%
from sklearn.impute import SimpleImputer

# %%
# Let's first check for NaN values
print("Columns with NaN values:")
print(df.isna().sum())

# Calculate the percentage of NaN values in each column
nan_percentage = df.isna().sum() / len(df) * 100
print("\nPercentage of NaN values in each column:")
print(nan_percentage)

# Strategy 1: Remove rows with NaN values
df_cleaned = df.dropna()
print(f"\nShape after removing NaN rows: {df_cleaned.shape}")

# Strategy 2: Impute NaN values with mean
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

print(f"\nShape of X after imputation: {X_imputed.shape}")

# Check if there are any NaN values left after imputation
print(f"NaN values remaining after imputation: {np.isnan(X_imputed).sum()}")

# Proceed with the imputed dataset
X_scaled = StandardScaler().fit_transform(X_imputed)
# Out:
# Columns with NaN values:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# ...

# %%
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)
#
# Instantiate PCA
#
pca = PCA()
#
# Determine transformed features
#
X_train_pca = pca.fit_transform(X_train_std)
#
# Determine explained variance using explained_variance_ration_ attribute
#
exp_var_pca = pca.explained_variance_ratio_
#
# Cumulative sum of eigenvalues; This will be used to create step plot
# for visualizing the variance explained by each principal component.
#
cum_sum_eigenvalues = np.cumsum(exp_var_pca)
#
# Create the visualization plot
#
plt.bar(range(0,len(exp_var_pca)), exp_var_pca, alpha=0.5, align='center', label='Individual explained variance')
plt.step(range(0,len(cum_sum_eigenvalues)), cum_sum_eigenvalues, where='mid',label='Cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [raw]
# # Standardize the features
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# %% [raw]
# # ANSWER
# # Create an instance of PCA
# pca = PCA()
# # Fit Xs
# pca.fit(X_scaled)

# %%
# ANSWER
# Plot explained_variance_

# %%
# ANSWER
# Apply dimensionality reduction to Xs using transform

# %%
# ANSWER
# Create PairPlot of PCA

# %%
# Now we can create an instance of PCA and fit it
pca = PCA()
pca.fit(X_scaled)

# Plot the explained variance ratio
plt.figure(figsize=(10, 6))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.title('Explained Variance Ratio vs. Number of Components')
plt.grid(True)
plt.show()

# Define n_components (e.g., number of components that explain 95% of the variance)
n_components = np.argmax(np.cumsum(pca.explained_variance_ratio_) >= 0.95) + 1
print(f"Number of components explaining 95% of variance: {n_components}")

# Create a new PCA instance with the determined number of components
pca_final = PCA(n_components=n_components)

# Apply dimensionality reduction to X
X_pca = pca_final.fit_transform(X_scaled)

# Create a DataFrame with the PCA results
pca_df = pd.DataFrame(data=X_pca, columns=[f'PC{i+1}' for i in range(n_components)])
pca_df['diagnosis'] = y
# Out:
# Number of components explaining 95% of variance: 10

# %%
# Create PairPlot of PCA
plt.figure(figsize=(12, 10))
sns.pairplot(pca_df, hue='diagnosis', vars=[f'PC{i+1}' for i in range(min(n_components, 4))])
plt.suptitle('Pairplot of First 4 Principal Components', y=1.02)
plt.show()

# Print the explained variance ratio for each component
for i, ratio in enumerate(pca_final.explained_variance_ratio_):
    print(f"PC{i+1} explained variance ratio: {ratio:.4f}")

# Print the cumulative explained variance ratio
print(f"Cumulative explained variance ratio: {np.sum(pca_final.explained_variance_ratio_):.4f}")
# Out:
# PC1 explained variance ratio: 0.4427
# PC2 explained variance ratio: 0.1897
# PC3 explained variance ratio: 0.0939
# PC4 explained variance ratio: 0.0660
# PC5 explained variance ratio: 0.0550
# PC6 explained variance ratio: 0.0402
# PC7 explained variance ratio: 0.0225
# PC8 explained variance ratio: 0.0159
# PC9 explained variance ratio: 0.0139
# PC10 explained variance ratio: 0.0117
# Cumulative explained variance ratio: 0.9516

# %% [markdown]
# ### 7. Split Data to 80/20 and use PCA prior to a supervised learning task
#
# In this section we use PCA as a preprocessing step to a supervised learning algorithm.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# Split the original dataset 80/20. Then apply standard scaler followed by PCA.

# %% [raw]
# # First, let's check for NaN values
# print("Columns with NaN values:")
# print(X.isna().sum())
#
# # Calculate the percentage of NaN values in each column
# nan_percentage = X.isna().sum() / len(X) * 100
# print("\nPercentage of NaN values in each column:")
# print(nan_percentage)
#
# # Impute NaN values with mean
# imputer = SimpleImputer(strategy='mean')
# X_imputed = imputer.fit_transform(X)
#
# # Check if there are any NaN values left after imputation
# print(f"\nNaN values remaining after imputation: {np.isnan(X_imputed).sum()}")
#
# # Now proceed with the analysis using X_imputed instead of X

# %% [raw]
# # Drop the 'Unnamed: 32' column
# df = df.drop('Unnamed: 32', axis=1, errors='ignore')

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Apply PCA
pca = PCA(n_components=16)  (# Keep 95% of the variance)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

print(f"\nOriginal number of features: {X_train.shape[1]}")
print(f"Number of features after PCA: {X_train_pca.shape[1]}")
# Out:
# Original number of features: 30
# Number of features after PCA: 16

# %% [markdown]
# Apply a KNN algorithm on `X_train_scaled` and `X_train_scaled_pca` with 5 neighbours, then evaluate using `X_test_scaled` and `X_test_scaled_pca`. Has performance been impacted as a result of dimension reduction?

# %%
# Set KNN classifier to use 5 neighbours and fit to X_train_scaled
# Train and evaluate KNN without PCA
knn_original = KNeighborsClassifier(n_neighbors=5)
knn_original.fit(X_train_scaled, y_train)
y_pred_original = knn_original.predict(X_test_scaled)

print("\nKNN Performance without PCA:")
print("Classification Report:")
print(classification_report(y_test, y_pred_original))

# Test accuracy of KNN using standardised data
print(f"Accuracy: {accuracy_score(y_test, y_pred_original):.4f}")
# Out:
# KNN Performance without PCA:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        71
#            1       0.93      0.93      0.93        43
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# Accuracy: 0.9474

# %%
# Set KNN classifier to use 5 neighbours and fit to X_train_scaled_pca
# Train and evaluate KNN with PCA
knn_pca = KNeighborsClassifier(n_neighbors=5)
knn_pca.fit(X_train_pca, y_train)

# Test accuracy of KNN using standardised PCA-transformed data

# %%
# Train and evaluate KNN with PCA
knn_pca = KNeighborsClassifier(n_neighbors=5)
knn_pca.fit(X_train_pca, y_train)
y_pred_pca = knn_pca.predict(X_test_pca)

print("\nKNN Performance with PCA:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_pca):.4f}")
print("Classification Report:")
print(classification_report(y_test, y_pred_pca))
# Out:
# KNN Performance with PCA:
# Accuracy: 0.9561
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97        71
#            1       0.95      0.93      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
# Features
X_test_pca.shape
# Out:
# (114, 16)

# %%
X_test.shape
# Out:
# (114, 30)

# %%
# Cross-validation
cv_scores_original = cross_val_score(knn_original, X_train_scaled, y_train, cv=5)
print(f"\nCross-validation scores without PCA: {cv_scores_original}")
print(f"Mean CV score without PCA: {np.mean(cv_scores_original):.4f}")

cv_scores_pca = cross_val_score(knn_pca, X_train_pca, y_train, cv=5)
print(f"Cross-validation scores with PCA: {cv_scores_pca}")
print(f"Mean CV score with PCA: {np.mean(cv_scores_pca):.4f}")
# Out:
# Cross-validation scores without PCA: [1. 1. 1. 1. 1.]
# Mean CV score without PCA: 1.0000
# Cross-validation scores with PCA: [1. 1. 1. 1. 1.]
# Mean CV score with PCA: 1.0000

# %%
# Compare the performance
acc_diff = accuracy_score(y_test, y_pred_pca) - accuracy_score(y_test, y_pred_original)
print(f"\nDifference in accuracy (PCA - Original): {acc_diff:.4f}")
# Out:
# Difference in accuracy (PCA - Original): 0.0000

# %% [markdown]
# **References**
#
# [Breast Cancer Wisconsin (Diagnostic) Data Set](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data/downloads/breast-cancer-wisconsin-data.zip/2)
#
# [Breast Cancer Machine Learning Prediction](https://gtraskas.github.io/post/breast_cancer/)
#
# [Understanding PCA (Principal Component Analysis) with Python](https://towardsdatascience.com/dive-into-pca-principal-component-analysis-with-python-43ded13ead21)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2024 Institute of Data
#
#
# ---
#
#
#
# ---
